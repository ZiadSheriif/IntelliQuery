# %%
nbits = 3  # number of hyperplanes and binary vals to produce
d = 70 # vector dimensions

# %%
import numpy as np
# create a set of 4 hyperplanes, with 2 dimensions
plane_norms = np.random.rand(nbits, d) - .5
plane_norms
# Out:
# array([[ 0.10528561,  0.30868108,  0.34474444,  0.27493634,  0.06282775,
#         -0.10183707,  0.01281022,  0.30755781,  0.47169295, -0.09033511,
#         -0.20263134,  0.08857188,  0.03453791, -0.2060363 , -0.47659952,
#          0.3749657 , -0.05721931, -0.18100972,  0.379527  , -0.45645971,
#          0.27206108, -0.29759044, -0.03814058, -0.2038863 ,  0.22248207,
#         -0.16038877, -0.09695367,  0.06524386,  0.29626737, -0.42654047,
#          0.4435749 , -0.07275007, -0.14411584,  0.22915059,  0.05615071,
#          0.37028483, -0.35808438, -0.0555    , -0.21839631, -0.49342616,
#         -0.07104715,  0.2913637 ,  0.36957037,  0.16528891,  0.25029101,
#         -0.08316107,  0.28703543,  0.42225707, -0.45280771, -0.25758351,
#         -0.30172331, -0.43735424,  0.23691898, -0.49313502, -0.43809558,
#         -0.21956662, -0.35070012, -0.49251654, -0.47081756,  0.27513195,
#          0.28871859,  0.38711786,  0.43967285, -0.09585003, -0.14690483,
#         -0.21304337,  0.48727231,  0.16880592,  0.1492045 ,  0.01726882],
#        [-0.25795136,  0.10520494,  0.03652868, -0.49498006,  0.48678914,
#          0.27616005,  0.35963602, -0.03421182,  0.44708103,  0.48639649,
#         -0.40968693, -0.43592424,  0.33621332,  0.33928909,  0.18186355,
#          0.24763945, -0.41085763, -0.24118493,  0.06978923, -0.40801998,
#         -0.38872322,  0.29141484,  0.44953653,  0.14854255, -0.42965771,
#         -0.14223905,  0.06974482,  0.26659237,  0.26535628, -0.34256927,
#          0.33636147,  0.11868279,  0.238596  , -0.07964285, -0.32114471,
#          0.27294106, -0.02096068, -0.04806644, -0.25707161, -0.10186781,
#         -0.39264292, -0.37109092,  0.25029489, -0.36511189,  0.0554983 ,
#         -0.37605923, -0.11232984, -0.38054741,  0.05728261, -0.32586945,
#          0.39035755, -0.46301672,  0.36378079,  0.1938946 ,  0.00318005,
#         -0.13233081,  0.09941155, -0.46432975,  0.0722078 , -0.41378651,
#         -0.05508854, -0.3777088 , -0.18322766, -0.03277914, -0.15486043,
#         -0.46752355, -0.47741207,  0.14544057,  0.40160305, -0.11317855],
#        [ 0.23692234,  0.26175124, -0.01644712,  0.47668596,  0.25343402,
#          0.1144655 ,  0.22039665, -0.17750236, -0.12316017, -0.00857771,
#         -0.26481955,  0.46232338, -0.04817458,  0.23763868, -0.35180508,
#         -0.19332736,  0.11238341,  0.35661089, -0.37329505,  0.42066564,
#         -0.35791026,  0.40895038, -0.30065915,  0.01171094, -0.47954737,
#          0.13929376, -0.24371011,  0.25998486,  0.20350885, -0.30584419,
#         -0.08193399, -0.2226616 , -0.19675881, -0.14157399, -0.08029205,
#         -0.44366982,  0.08731621,  0.27684222,  0.29157461,  0.31030076,
#          0.29862658,  0.21355292, -0.41590586, -0.20261408, -0.2379568 ,
#          0.0678172 , -0.22441887,  0.41526701, -0.31291195, -0.08086893,
#          0.38901211,  0.04986125, -0.4613704 , -0.13337183,  0.33119645,
#          0.15933441, -0.42177938, -0.07228431, -0.00092263, -0.45799984,
#          0.18974878,  0.25477833, -0.4736754 ,  0.2781725 , -0.0256128 ,
#         -0.2658082 ,  0.10961357, -0.42049345,  0.44865978,  0.46719829]])

# %%
a=np.random.random((1, 70))
b=np.random.random((1, 70))
c=np.random.random((1, 70))
# Repeat the array to generate a 1x70 array
print(a)
print(b)
# Out:
# [[0.56866406 0.73002874 0.09406151 0.2214195  0.20858532 0.91643939
#   0.71837935 0.53928256 0.73659895 0.44597345 0.4974472  0.98040081
#   0.28900216 0.47110458 0.79386238 0.86140046 0.01874575 0.0514817
#   0.10487766 0.2256683  0.97618355 0.7396569  0.14192572 0.47612877
#   0.34493137 0.89195156 0.55488749 0.62725418 0.2831146  0.68202307
#   0.47947899 0.59790498 0.52113685 0.80529919 0.01339397 0.05064725
#   0.67159858 0.76455962 0.30508496 0.12241166 0.88329478 0.69676958
#   0.48559382 0.27159054 0.77798699 0.43164465 0.82112227 0.5553929
#   0.15830124 0.90357046 0.77589125 0.41025865 0.81896346 0.12602244
#   0.92899879 0.26871323 0.1397371  0.04902069 0.00524174 0.16936331
#   0.38689565 0.64625745 0.08947511 0.65124614 0.43090907 0.40469619
#   0.91291688 0.83704579 0.20475307 0.99227755]]
# [[0.20211514 0.05098373 0.03212779 0.03971936 0.84334843 0.79532802
#   0.48480893 0.95882055 0.61638288 0.366436   0.58907688 0.36809534
#   0.62727349 0.04566719 0.87144503 0.58970865 0.54133806 0.43343093
#   0.40310875 0.38148045 0.91311603 0.39211761 0.63364099 0.46415211
#   0.49916673 0.08100873 0.1237818  0.57324546 0.67901876 0.82617852
#   0.22869672 0.66060377 0.09305492 0.89698811 0.6366337  0.08254209
#   0.67523331 0.72336687 0.740391   0.24018064 0.74189156 0.96532694
#   0.49448464 0.11273828 0.88105964 0.45079897 0.59731631 0.5345803
#   0.23015661 0.14504441 0.14762568 0.83227909 0.20666756 0.36062437
#   0.14762246 0.45673977 0.20790983 0.6665209  0.53024088 0.46283968
#   0.64265088 0.51639158 0.50969123 0.05463836 0.51472087 0.04265972
#   0.23963661 0.88675285 0.37778724 0.1332672 ]]

# %%
# calculate the dot product for each of these
a_dot = np.dot(a, plane_norms.T)
b_dot = np.dot(b, plane_norms.T)
c_dot = np.dot(c, plane_norms.T)
a_dot
# Out:
# array([[ 0.83110985, -1.12373252,  0.96540596]])

# %%
# we know that a positive dot product == +ve side of hyperplane
# and negative dot product == -ve side of hyperplane
a_dot = a_dot > 0
b_dot = b_dot > 0
c_dot = c_dot > 0
a_dot
# Out:
# array([[ True, False,  True]])

# %%
# convert our boolean arrays to int arrays to make bucketing
# easier (although is okay to use boolean for Hamming distance)
a_dot = a_dot.astype(int)[0]
b_dot = b_dot.astype(int)[0]
c_dot = c_dot.astype(int)[0]
a_dot
# Out:
# array([1, 0, 1])

# %%
vectors = [a_dot, b_dot, c_dot]
buckets = {}
i = 0

for i in range(len(vectors)):
    # convert from array to string
    hash_str = ''.join(vectors[i].astype(str))
    print(hash_str)
    # create bucket if it doesn't exist
    if hash_str not in buckets.keys():
        buckets[hash_str] = []
    # add vector position to bucket
    buckets[hash_str].append(i)

print(buckets)
# Out:
# 101
# 100
# 000
# {'101': [0], '100': [1], '000': [2]}

# %%
 #! for tesing input query

query=np.random.random((1, 70))
print(query)

query_dot = np.dot(query, plane_norms.T)
query_dot = query_dot > 0
query_dot = query_dot.astype(int)[0]

# Convert the query array to a string
query_hash_str = ''.join(query_dot.astype(str))

# Check which bucket the query belongs to
if query_hash_str in buckets.keys():
    bucket_containing_query = buckets[query_hash_str]
    print("Query belongs to bucket:", bucket_containing_query)
else:
    print("Query doesn't match any existing buckets")
    print(0)
# Out:
# [[8.92143098e-01 2.03295315e-01 5.32743152e-01 5.40299578e-02
#   5.55712071e-01 9.70755316e-01 3.46818733e-01 3.64164063e-01
#   7.60145573e-01 6.74914140e-01 7.21642494e-01 5.84276935e-01
#   7.98889866e-03 9.23933302e-01 9.02628240e-01 5.42659102e-03
#   6.75017695e-01 6.97307910e-01 5.74697461e-01 3.98330478e-01
#   2.77201392e-03 4.97519039e-02 5.84378872e-01 7.71885551e-03
#   4.34092179e-02 1.85355351e-01 7.06693074e-01 4.85362049e-01
#   4.77487850e-01 3.53853171e-01 1.34896342e-01 3.88181756e-01
#   3.85880011e-01 6.97103040e-02 3.73380586e-01 6.18254833e-01
#   9.08310914e-01 4.01782944e-01 9.93328788e-02 9.91926811e-01
#   5.57880051e-04 7.90679195e-02 1.45113346e-02 5.01959880e-01
#   3.07403486e-01 7.93676988e-01 8.00974577e-01 2.38562101e-01
#   3.39816625e-01 6.44951455e-01 1.15441239e-01 6.15670146e-01
#   5.08999479e-01 1.16559876e-01 3.18980122e-01 2.36477229e-01
#   8.41159150e-01 7.67986263e-02 8.08770220e-01 9.00869750e-01
#   6.23390157e-01 3.82061698e-01 4.40686423e-01 2.30491356e-01
#   4.80021748e-01 7.51341154e-01 5.79275260e-01 6.60066020e-01
#   7.72293202e-01 3.61014122e-01]]
# Query belongs to bucket: [2]
