# %%
from typing import Dict, List, Annotated
import struct
import numpy as np

class VecDBWorst:
    def __init__(self, file_path = "saved_db.bin", new_db = True) -> None:
        self.file_path = file_path
        if new_db:
            # just open new file to delete the old one
            with open(self.file_path, "w") as fout:
                # if you need to add any head to the file
                pass
    
    def insert_records(self, rows: List[Dict[int, Annotated[List[float], 70]]]):
        with open(self.file_path, "a+") as fout:
            for row in rows:
                id, embed = row["id"], row["embed"]
                row_str = f"{id}," + ",".join([str(e) for e in embed])
                print(row_str)
                fout.write(f"{row_str}\n")
        self._build_index()

    def insert_records_binary(self, rows: List[Dict[int, Annotated[List[float], 70]]]):
        with open(self.file_path, "ab") as fout:  # Open the file in binary mode for appending
            for row in rows:
                id, embed = row["id"], row["embed"]
                # Pack the data into a binary format
                data = struct.pack(f"I{70}f", id, *embed)
                fout.write(data)
        self._build_index()

    def calculate_offset(self, record_id: int) -> int:
        # Calculate the offset for a given record ID
        record_size = struct.calcsize("I70f")
        return record_id * record_size

    def read_record_by_id(self, record_id: int) -> Dict[int, Annotated[List[float], 70]]:
        record_size = struct.calcsize("I70f")
        offset = self.calculate_offset(record_id)

        with open(self.file_path, "rb") as fin:
            fin.seek(offset)  # Move the file pointer to the calculated offset
            data = fin.read(record_size)
            if not data:
                return {}  # Record not found

            # Unpack the binary data into a dictionary
            unpacked_data = struct.unpack("I70f", data)
            id_value, floats = unpacked_data[0], unpacked_data[1:]

            # Create and return the record dictionary
            record = {"id": id_value, "embed": list(floats)}
            return {record_id: record}

    def retrive(self, query: Annotated[List[float], 70], top_k = 5):
        scores = []
        with open(self.file_path, "r") as fin:
            for row in fin.readlines():
                row_splits = row.split(",")
                id = int(row_splits[0])
                embed = [float(e) for e in row_splits[1:]]
                score = self._cal_score(query, embed)
                scores.append((score, id))
        # here we assume that if two rows have the same score, return the lowest ID
        scores = sorted(scores, reverse=True)[:top_k]
        return [s[1] for s in scores]
    
    def _cal_score(self, vec1, vec2):
        dot_product = np.dot(vec1, vec2)
        norm_vec1 = np.linalg.norm(vec1)
        norm_vec2 = np.linalg.norm(vec2)
        cosine_similarity = dot_product / (norm_vec1 * norm_vec2)
        return cosine_similarity

    def _build_index(self):
        pass

# %%
import numpy as np

# Function to generate random embeddings
def generate_embeddings(num_records, embedding_dim):
    return [np.random.rand(embedding_dim).tolist() for _ in range(num_records)]

# Create an instance of VecDB
db = VecDBWorst()

# Define parameters
total_records = 20000000  # 20 million records
chunk_size = 10000  # Insert records in chunks of 10,000

# Insert records in chunks
for i in range(0, total_records, chunk_size):
    chunk_records = []
    for j in range(i + 1, i + chunk_size + 1):
        if j > total_records:
            break
        record = {"id": j, "embed": generate_embeddings(1, 70)[0]}
        # record = {"id": j, "embed": np.full(70,j)}
        #  make this size of record to be fixed 1500 bytes
        # size_of_dummy_needed = 1500 - len(record["embed"])
        
        chunk_records.append(record)

    db.insert_records_binary(chunk_records)
    print(f"Inserted {len(chunk_records)} records. Total records inserted: {j}")

print("Insertion complete.")
# Out:
# Inserted 10000 records. Total records inserted: 10000
# Inserted 10000 records. Total records inserted: 20000
# Inserted 10000 records. Total records inserted: 30000
# Inserted 10000 records. Total records inserted: 40000
# Inserted 10000 records. Total records inserted: 50000
# Inserted 10000 records. Total records inserted: 60000
# Inserted 10000 records. Total records inserted: 70000
# Inserted 10000 records. Total records inserted: 80000
# Inserted 10000 records. Total records inserted: 90000
# Inserted 10000 records. Total records inserted: 100000
# Inserted 10000 records. Total records inserted: 110000
# Inserted 10000 records. Total records inserted: 120000
# Inserted 10000 records. Total records inserted: 130000
# Inserted 10000 records. Total records inserted: 140000
# Inserted 10000 records. Total records inserted: 150000
# Inserted 10000 records. Total records inserted: 160000
# Inserted 10000 records. Total records inserted: 170000
# Inserted 10000 records. Total records inserted: 180000
# Inserted 10000 records. Total records inserted: 190000
# Inserted 10000 records. Total records inserted: 200000
# Inserted 10000 records. Total records inserted: 210000
# Inserted 10000 records. Total records inserted: 220000
# Inserted 10000 records. Total records inserted: 230000
# Inserted 10000 records. Total records inserted: 240000
# Inserted 10000 records. Total records inserted: 250000
# Inserted 10000 records. Total records inserted: 260000
# Inserted 10000 records. Total records inserted: 270000
# Inserted 10000 records. Total records inserted: 280000
# Inserted 10000 records. Total records inserted: 290000
# Inserted 10000 records. Total records inserted: 300000
# Inserted 10000 records. Total records inserted: 310000
# Inserted 10000 records. Total records inserted: 320000
# Inserted 10000 records. Total records inserted: 330000
# Inserted 10000 records. Total records inserted: 340000
# Inserted 10000 records. Total records inserted: 350000
# Inserted 10000 records. Total records inserted: 360000
# Inserted 10000 records. Total records inserted: 370000
# Inserted 10000 records. Total records inserted: 380000
# Inserted 10000 records. Total records inserted: 390000
# Inserted 10000 records. Total records inserted: 400000
# Inserted 10000 records. Total records inserted: 410000
# Inserted 10000 records. Total records inserted: 420000
# Inserted 10000 records. Total records inserted: 430000
# Inserted 10000 records. Total records inserted: 440000
# Inserted 10000 records. Total records inserted: 450000
# Inserted 10000 records. Total records inserted: 460000
# Inserted 10000 records. Total records inserted: 470000
# Inserted 10000 records. Total records inserted: 480000
# Inserted 10000 records. Total records inserted: 490000
# Inserted 10000 records. Total records inserted: 500000
# Inserted 10000 records. Total records inserted: 510000
# Inserted 10000 records. Total records inserted: 520000
# Inserted 10000 records. Total records inserted: 530000
# Inserted 10000 records. Total records inserted: 540000
# Inserted 10000 records. Total records inserted: 550000
# Inserted 10000 records. Total records inserted: 560000
# Inserted 10000 records. Total records inserted: 570000
# Inserted 10000 records. Total records inserted: 580000
# Inserted 10000 records. Total records inserted: 590000
# Inserted 10000 records. Total records inserted: 600000
# Inserted 10000 records. Total records inserted: 610000
# Inserted 10000 records. Total records inserted: 620000
# Inserted 10000 records. Total records inserted: 630000
# Inserted 10000 records. Total records inserted: 640000
# Inserted 10000 records. Total records inserted: 650000
# Inserted 10000 records. Total records inserted: 660000
# Inserted 10000 records. Total records inserted: 670000
# Inserted 10000 records. Total records inserted: 680000
# Inserted 10000 records. Total records inserted: 690000
# Inserted 10000 records. Total records inserted: 700000
# Inserted 10000 records. Total records inserted: 710000
# Inserted 10000 records. Total records inserted: 720000
# Inserted 10000 records. Total records inserted: 730000
# Inserted 10000 records. Total records inserted: 740000
# Inserted 10000 records. Total records inserted: 750000
# Inserted 10000 records. Total records inserted: 760000
# Inserted 10000 records. Total records inserted: 770000
# Inserted 10000 records. Total records inserted: 780000
# Inserted 10000 records. Total records inserted: 790000
# Inserted 10000 records. Total records inserted: 800000
# Inserted 10000 records. Total records inserted: 810000
# Inserted 10000 records. Total records inserted: 820000
# Inserted 10000 records. Total records inserted: 830000
# Inserted 10000 records. Total records inserted: 840000
# Inserted 10000 records. Total records inserted: 850000
# Inserted 10000 records. Total records inserted: 860000
# Inserted 10000 records. Total records inserted: 870000
# Inserted 10000 records. Total records inserted: 880000
# Inserted 10000 records. Total records inserted: 890000
# Inserted 10000 records. Total records inserted: 900000
# Inserted 10000 records. Total records inserted: 910000
# Inserted 10000 records. Total records inserted: 920000
# Inserted 10000 records. Total records inserted: 930000
# Inserted 10000 records. Total records inserted: 940000
# Inserted 10000 records. Total records inserted: 950000
# Inserted 10000 records. Total records inserted: 960000
# Inserted 10000 records. Total records inserted: 970000
# Inserted 10000 records. Total records inserted: 980000
# Inserted 10000 records. Total records inserted: 990000
# Inserted 10000 records. Total records inserted: 1000000
# Inserted 10000 records. Total records inserted: 1010000
# Inserted 10000 records. Total records inserted: 1020000
# Inserted 10000 records. Total records inserted: 1030000
# Inserted 10000 records. Total records inserted: 1040000
# Inserted 10000 records. Total records inserted: 1050000
# Inserted 10000 records. Total records inserted: 1060000
# Inserted 10000 records. Total records inserted: 1070000
# Inserted 10000 records. Total records inserted: 1080000
# Inserted 10000 records. Total records inserted: 1090000
# Inserted 10000 records. Total records inserted: 1100000
# Inserted 10000 records. Total records inserted: 1110000
# Inserted 10000 records. Total records inserted: 1120000
# Inserted 10000 records. Total records inserted: 1130000
# Inserted 10000 records. Total records inserted: 1140000
# Inserted 10000 records. Total records inserted: 1150000
# Inserted 10000 records. Total records inserted: 1160000
# Inserted 10000 records. Total records inserted: 1170000
# Inserted 10000 records. Total records inserted: 1180000
# Inserted 10000 records. Total records inserted: 1190000
# Inserted 10000 records. Total records inserted: 1200000
# Inserted 10000 records. Total records inserted: 1210000
# Inserted 10000 records. Total records inserted: 1220000
# Inserted 10000 records. Total records inserted: 1230000
# Inserted 10000 records. Total records inserted: 1240000
# Inserted 10000 records. Total records inserted: 1250000
# Inserted 10000 records. Total records inserted: 1260000
# Inserted 10000 records. Total records inserted: 1270000
# Inserted 10000 records. Total records inserted: 1280000
# Inserted 10000 records. Total records inserted: 1290000
# Inserted 10000 records. Total records inserted: 1300000
# Inserted 10000 records. Total records inserted: 1310000
# Inserted 10000 records. Total records inserted: 1320000
# Inserted 10000 records. Total records inserted: 1330000
# Inserted 10000 records. Total records inserted: 1340000
# Inserted 10000 records. Total records inserted: 1350000
# Inserted 10000 records. Total records inserted: 1360000
# Inserted 10000 records. Total records inserted: 1370000
# Inserted 10000 records. Total records inserted: 1380000
# Inserted 10000 records. Total records inserted: 1390000
# Inserted 10000 records. Total records inserted: 1400000
# Inserted 10000 records. Total records inserted: 1410000
# Inserted 10000 records. Total records inserted: 1420000
# Inserted 10000 records. Total records inserted: 1430000
# Inserted 10000 records. Total records inserted: 1440000
# Inserted 10000 records. Total records inserted: 1450000
# Inserted 10000 records. Total records inserted: 1460000
# Inserted 10000 records. Total records inserted: 1470000
# Inserted 10000 records. Total records inserted: 1480000
# Inserted 10000 records. Total records inserted: 1490000
# Inserted 10000 records. Total records inserted: 1500000
# Inserted 10000 records. Total records inserted: 1510000
# Inserted 10000 records. Total records inserted: 1520000
# Inserted 10000 records. Total records inserted: 1530000
# Inserted 10000 records. Total records inserted: 1540000
# Inserted 10000 records. Total records inserted: 1550000
# Inserted 10000 records. Total records inserted: 1560000
# Inserted 10000 records. Total records inserted: 1570000
# Inserted 10000 records. Total records inserted: 1580000
# Inserted 10000 records. Total records inserted: 1590000
# Inserted 10000 records. Total records inserted: 1600000
# Inserted 10000 records. Total records inserted: 1610000
# Inserted 10000 records. Total records inserted: 1620000
# Inserted 10000 records. Total records inserted: 1630000
# Inserted 10000 records. Total records inserted: 1640000
# Inserted 10000 records. Total records inserted: 1650000
# Inserted 10000 records. Total records inserted: 1660000
# Inserted 10000 records. Total records inserted: 1670000
# Inserted 10000 records. Total records inserted: 1680000
# Inserted 10000 records. Total records inserted: 1690000
# Inserted 10000 records. Total records inserted: 1700000
# Inserted 10000 records. Total records inserted: 1710000
# Inserted 10000 records. Total records inserted: 1720000
# Inserted 10000 records. Total records inserted: 1730000
# Inserted 10000 records. Total records inserted: 1740000
# Inserted 10000 records. Total records inserted: 1750000
# Inserted 10000 records. Total records inserted: 1760000
# Inserted 10000 records. Total records inserted: 1770000
# Inserted 10000 records. Total records inserted: 1780000
# Inserted 10000 records. Total records inserted: 1790000
# Inserted 10000 records. Total records inserted: 1800000
# Inserted 10000 records. Total records inserted: 1810000
# Inserted 10000 records. Total records inserted: 1820000
# Inserted 10000 records. Total records inserted: 1830000
# Inserted 10000 records. Total records inserted: 1840000
# Inserted 10000 records. Total records inserted: 1850000
# Inserted 10000 records. Total records inserted: 1860000
# Inserted 10000 records. Total records inserted: 1870000
# Inserted 10000 records. Total records inserted: 1880000
# Inserted 10000 records. Total records inserted: 1890000
# Inserted 10000 records. Total records inserted: 1900000
# Inserted 10000 records. Total records inserted: 1910000
# Inserted 10000 records. Total records inserted: 1920000
# Inserted 10000 records. Total records inserted: 1930000
# Inserted 10000 records. Total records inserted: 1940000
# Inserted 10000 records. Total records inserted: 1950000
# Inserted 10000 records. Total records inserted: 1960000
# Inserted 10000 records. Total records inserted: 1970000
# Inserted 10000 records. Total records inserted: 1980000
# Inserted 10000 records. Total records inserted: 1990000
# Inserted 10000 records. Total records inserted: 2000000
# Inserted 10000 records. Total records inserted: 2010000
# Inserted 10000 records. Total records inserted: 2020000
# Inserted 10000 records. Total records inserted: 2030000
# Inserted 10000 records. Total records inserted: 2040000
# Inserted 10000 records. Total records inserted: 2050000
# Inserted 10000 records. Total records inserted: 2060000
# Inserted 10000 records. Total records inserted: 2070000
# Inserted 10000 records. Total records inserted: 2080000
# Inserted 10000 records. Total records inserted: 2090000
# Inserted 10000 records. Total records inserted: 2100000
# Inserted 10000 records. Total records inserted: 2110000
# Inserted 10000 records. Total records inserted: 2120000
# Inserted 10000 records. Total records inserted: 2130000
# Inserted 10000 records. Total records inserted: 2140000
# Inserted 10000 records. Total records inserted: 2150000
# Inserted 10000 records. Total records inserted: 2160000
# Inserted 10000 records. Total records inserted: 2170000
# Inserted 10000 records. Total records inserted: 2180000
# Inserted 10000 records. Total records inserted: 2190000
# Inserted 10000 records. Total records inserted: 2200000
# Inserted 10000 records. Total records inserted: 2210000
# Inserted 10000 records. Total records inserted: 2220000
# Inserted 10000 records. Total records inserted: 2230000
# Inserted 10000 records. Total records inserted: 2240000
# Inserted 10000 records. Total records inserted: 2250000
# Inserted 10000 records. Total records inserted: 2260000
# Inserted 10000 records. Total records inserted: 2270000
# Inserted 10000 records. Total records inserted: 2280000
# Inserted 10000 records. Total records inserted: 2290000
# Inserted 10000 records. Total records inserted: 2300000
# Inserted 10000 records. Total records inserted: 2310000
# Inserted 10000 records. Total records inserted: 2320000
# Inserted 10000 records. Total records inserted: 2330000
# Inserted 10000 records. Total records inserted: 2340000
# Inserted 10000 records. Total records inserted: 2350000
# Inserted 10000 records. Total records inserted: 2360000
# Inserted 10000 records. Total records inserted: 2370000
# Inserted 10000 records. Total records inserted: 2380000
# Inserted 10000 records. Total records inserted: 2390000
# Inserted 10000 records. Total records inserted: 2400000
# Inserted 10000 records. Total records inserted: 2410000
# Inserted 10000 records. Total records inserted: 2420000
# Inserted 10000 records. Total records inserted: 2430000
# Inserted 10000 records. Total records inserted: 2440000
# Inserted 10000 records. Total records inserted: 2450000
# Inserted 10000 records. Total records inserted: 2460000
# Inserted 10000 records. Total records inserted: 2470000
# Inserted 10000 records. Total records inserted: 2480000
# Inserted 10000 records. Total records inserted: 2490000
# Inserted 10000 records. Total records inserted: 2500000
# Inserted 10000 records. Total records inserted: 2510000
# Inserted 10000 records. Total records inserted: 2520000
# Inserted 10000 records. Total records inserted: 2530000
# Inserted 10000 records. Total records inserted: 2540000
# Inserted 10000 records. Total records inserted: 2550000
# Inserted 10000 records. Total records inserted: 2560000
# Inserted 10000 records. Total records inserted: 2570000
# Inserted 10000 records. Total records inserted: 2580000
# Inserted 10000 records. Total records inserted: 2590000
# Inserted 10000 records. Total records inserted: 2600000
# Inserted 10000 records. Total records inserted: 2610000
# Inserted 10000 records. Total records inserted: 2620000
# Inserted 10000 records. Total records inserted: 2630000
# Inserted 10000 records. Total records inserted: 2640000
# Inserted 10000 records. Total records inserted: 2650000
# Inserted 10000 records. Total records inserted: 2660000
# Inserted 10000 records. Total records inserted: 2670000
# Inserted 10000 records. Total records inserted: 2680000
# Inserted 10000 records. Total records inserted: 2690000
# Inserted 10000 records. Total records inserted: 2700000
# Inserted 10000 records. Total records inserted: 2710000
# Inserted 10000 records. Total records inserted: 2720000
# Inserted 10000 records. Total records inserted: 2730000
# Inserted 10000 records. Total records inserted: 2740000
# Inserted 10000 records. Total records inserted: 2750000
# Inserted 10000 records. Total records inserted: 2760000
# Inserted 10000 records. Total records inserted: 2770000
# Inserted 10000 records. Total records inserted: 2780000
# Inserted 10000 records. Total records inserted: 2790000
# Inserted 10000 records. Total records inserted: 2800000
# Inserted 10000 records. Total records inserted: 2810000
# Inserted 10000 records. Total records inserted: 2820000
# Inserted 10000 records. Total records inserted: 2830000
# Inserted 10000 records. Total records inserted: 2840000
# Inserted 10000 records. Total records inserted: 2850000
# Inserted 10000 records. Total records inserted: 2860000
# Inserted 10000 records. Total records inserted: 2870000
# Inserted 10000 records. Total records inserted: 2880000
# Inserted 10000 records. Total records inserted: 2890000
# Inserted 10000 records. Total records inserted: 2900000
# Inserted 10000 records. Total records inserted: 2910000
# Inserted 10000 records. Total records inserted: 2920000
# Inserted 10000 records. Total records inserted: 2930000
# Inserted 10000 records. Total records inserted: 2940000
# Inserted 10000 records. Total records inserted: 2950000
# Inserted 10000 records. Total records inserted: 2960000
# Inserted 10000 records. Total records inserted: 2970000
# Inserted 10000 records. Total records inserted: 2980000
# Inserted 10000 records. Total records inserted: 2990000
# Inserted 10000 records. Total records inserted: 3000000
# Inserted 10000 records. Total records inserted: 3010000
# Inserted 10000 records. Total records inserted: 3020000
# Inserted 10000 records. Total records inserted: 3030000
# Inserted 10000 records. Total records inserted: 3040000
# Inserted 10000 records. Total records inserted: 3050000
# Inserted 10000 records. Total records inserted: 3060000
# Inserted 10000 records. Total records inserted: 3070000
# Inserted 10000 records. Total records inserted: 3080000
# Inserted 10000 records. Total records inserted: 3090000
# Inserted 10000 records. Total records inserted: 3100000
# Inserted 10000 records. Total records inserted: 3110000
# Inserted 10000 records. Total records inserted: 3120000
# Inserted 10000 records. Total records inserted: 3130000
# Inserted 10000 records. Total records inserted: 3140000
# Inserted 10000 records. Total records inserted: 3150000
# Inserted 10000 records. Total records inserted: 3160000
# Inserted 10000 records. Total records inserted: 3170000
# Inserted 10000 records. Total records inserted: 3180000
# Inserted 10000 records. Total records inserted: 3190000
# Inserted 10000 records. Total records inserted: 3200000
# Inserted 10000 records. Total records inserted: 3210000
# Inserted 10000 records. Total records inserted: 3220000
# Inserted 10000 records. Total records inserted: 3230000
# Inserted 10000 records. Total records inserted: 3240000
# Inserted 10000 records. Total records inserted: 3250000
# Inserted 10000 records. Total records inserted: 3260000
# Inserted 10000 records. Total records inserted: 3270000
# Inserted 10000 records. Total records inserted: 3280000
# Inserted 10000 records. Total records inserted: 3290000
# Inserted 10000 records. Total records inserted: 3300000
# Inserted 10000 records. Total records inserted: 3310000
# Inserted 10000 records. Total records inserted: 3320000
# Inserted 10000 records. Total records inserted: 3330000
# Inserted 10000 records. Total records inserted: 3340000
# Inserted 10000 records. Total records inserted: 3350000
# Inserted 10000 records. Total records inserted: 3360000
# Inserted 10000 records. Total records inserted: 3370000
# Inserted 10000 records. Total records inserted: 3380000
# Inserted 10000 records. Total records inserted: 3390000
# Inserted 10000 records. Total records inserted: 3400000
# Inserted 10000 records. Total records inserted: 3410000
# Inserted 10000 records. Total records inserted: 3420000
# Inserted 10000 records. Total records inserted: 3430000
# Inserted 10000 records. Total records inserted: 3440000
# Inserted 10000 records. Total records inserted: 3450000
# Inserted 10000 records. Total records inserted: 3460000
# Inserted 10000 records. Total records inserted: 3470000
# Inserted 10000 records. Total records inserted: 3480000
# Inserted 10000 records. Total records inserted: 3490000
# Inserted 10000 records. Total records inserted: 3500000
# Inserted 10000 records. Total records inserted: 3510000
# Inserted 10000 records. Total records inserted: 3520000
# Inserted 10000 records. Total records inserted: 3530000
# Inserted 10000 records. Total records inserted: 3540000
# Inserted 10000 records. Total records inserted: 3550000
# Inserted 10000 records. Total records inserted: 3560000
# Inserted 10000 records. Total records inserted: 3570000
# Inserted 10000 records. Total records inserted: 3580000
# Inserted 10000 records. Total records inserted: 3590000
# Inserted 10000 records. Total records inserted: 3600000
# Inserted 10000 records. Total records inserted: 3610000
# Inserted 10000 records. Total records inserted: 3620000
# Inserted 10000 records. Total records inserted: 3630000
# Inserted 10000 records. Total records inserted: 3640000
# Inserted 10000 records. Total records inserted: 3650000
# Inserted 10000 records. Total records inserted: 3660000
# Inserted 10000 records. Total records inserted: 3670000
# Inserted 10000 records. Total records inserted: 3680000
# Inserted 10000 records. Total records inserted: 3690000
# Inserted 10000 records. Total records inserted: 3700000
# Inserted 10000 records. Total records inserted: 3710000
# Inserted 10000 records. Total records inserted: 3720000
# Inserted 10000 records. Total records inserted: 3730000
# Inserted 10000 records. Total records inserted: 3740000
# Inserted 10000 records. Total records inserted: 3750000
# Inserted 10000 records. Total records inserted: 3760000
# Inserted 10000 records. Total records inserted: 3770000
# Inserted 10000 records. Total records inserted: 3780000
# Inserted 10000 records. Total records inserted: 3790000
# Inserted 10000 records. Total records inserted: 3800000
# Inserted 10000 records. Total records inserted: 3810000
# Inserted 10000 records. Total records inserted: 3820000
# Inserted 10000 records. Total records inserted: 3830000
# Inserted 10000 records. Total records inserted: 3840000
# Inserted 10000 records. Total records inserted: 3850000
# Inserted 10000 records. Total records inserted: 3860000
# Inserted 10000 records. Total records inserted: 3870000
# Inserted 10000 records. Total records inserted: 3880000
# Inserted 10000 records. Total records inserted: 3890000
# Inserted 10000 records. Total records inserted: 3900000
# Inserted 10000 records. Total records inserted: 3910000
# Inserted 10000 records. Total records inserted: 3920000
# Inserted 10000 records. Total records inserted: 3930000
# Inserted 10000 records. Total records inserted: 3940000
# Inserted 10000 records. Total records inserted: 3950000
# Inserted 10000 records. Total records inserted: 3960000
# Inserted 10000 records. Total records inserted: 3970000
# Inserted 10000 records. Total records inserted: 3980000
# Inserted 10000 records. Total records inserted: 3990000
# Inserted 10000 records. Total records inserted: 4000000
# Inserted 10000 records. Total records inserted: 4010000
# Inserted 10000 records. Total records inserted: 4020000
# Inserted 10000 records. Total records inserted: 4030000
# Inserted 10000 records. Total records inserted: 4040000
# Inserted 10000 records. Total records inserted: 4050000
# Inserted 10000 records. Total records inserted: 4060000
# Inserted 10000 records. Total records inserted: 4070000
# Inserted 10000 records. Total records inserted: 4080000
# Inserted 10000 records. Total records inserted: 4090000
# Inserted 10000 records. Total records inserted: 4100000
# Inserted 10000 records. Total records inserted: 4110000
# Inserted 10000 records. Total records inserted: 4120000
# Inserted 10000 records. Total records inserted: 4130000
# Inserted 10000 records. Total records inserted: 4140000
# Inserted 10000 records. Total records inserted: 4150000
# Inserted 10000 records. Total records inserted: 4160000
# Inserted 10000 records. Total records inserted: 4170000
# Inserted 10000 records. Total records inserted: 4180000
# Inserted 10000 records. Total records inserted: 4190000
# Inserted 10000 records. Total records inserted: 4200000
# Inserted 10000 records. Total records inserted: 4210000
# Inserted 10000 records. Total records inserted: 4220000
# Inserted 10000 records. Total records inserted: 4230000
# Inserted 10000 records. Total records inserted: 4240000
# Inserted 10000 records. Total records inserted: 4250000
# Inserted 10000 records. Total records inserted: 4260000
# Inserted 10000 records. Total records inserted: 4270000
# Inserted 10000 records. Total records inserted: 4280000
# Inserted 10000 records. Total records inserted: 4290000
# Inserted 10000 records. Total records inserted: 4300000
# Inserted 10000 records. Total records inserted: 4310000
# Inserted 10000 records. Total records inserted: 4320000
# Inserted 10000 records. Total records inserted: 4330000
# Inserted 10000 records. Total records inserted: 4340000
# Inserted 10000 records. Total records inserted: 4350000
# Inserted 10000 records. Total records inserted: 4360000
# Inserted 10000 records. Total records inserted: 4370000
# Inserted 10000 records. Total records inserted: 4380000
# Inserted 10000 records. Total records inserted: 4390000
# Inserted 10000 records. Total records inserted: 4400000
# Inserted 10000 records. Total records inserted: 4410000
# Inserted 10000 records. Total records inserted: 4420000
# Inserted 10000 records. Total records inserted: 4430000
# Inserted 10000 records. Total records inserted: 4440000
# Inserted 10000 records. Total records inserted: 4450000
# Inserted 10000 records. Total records inserted: 4460000
# Inserted 10000 records. Total records inserted: 4470000
# Inserted 10000 records. Total records inserted: 4480000
# Inserted 10000 records. Total records inserted: 4490000
# Inserted 10000 records. Total records inserted: 4500000
# Inserted 10000 records. Total records inserted: 4510000
# Inserted 10000 records. Total records inserted: 4520000
# Inserted 10000 records. Total records inserted: 4530000
# Inserted 10000 records. Total records inserted: 4540000
# Inserted 10000 records. Total records inserted: 4550000
# Inserted 10000 records. Total records inserted: 4560000
# Inserted 10000 records. Total records inserted: 4570000
# Inserted 10000 records. Total records inserted: 4580000
# Inserted 10000 records. Total records inserted: 4590000
# Inserted 10000 records. Total records inserted: 4600000
# Inserted 10000 records. Total records inserted: 4610000
# Inserted 10000 records. Total records inserted: 4620000
# Inserted 10000 records. Total records inserted: 4630000
# Inserted 10000 records. Total records inserted: 4640000
# Inserted 10000 records. Total records inserted: 4650000
# Inserted 10000 records. Total records inserted: 4660000
# Inserted 10000 records. Total records inserted: 4670000
# Inserted 10000 records. Total records inserted: 4680000
# Inserted 10000 records. Total records inserted: 4690000
# Inserted 10000 records. Total records inserted: 4700000
# Inserted 10000 records. Total records inserted: 4710000
# Inserted 10000 records. Total records inserted: 4720000
# Inserted 10000 records. Total records inserted: 4730000
# Inserted 10000 records. Total records inserted: 4740000
# Inserted 10000 records. Total records inserted: 4750000
# Inserted 10000 records. Total records inserted: 4760000
# Inserted 10000 records. Total records inserted: 4770000
# Inserted 10000 records. Total records inserted: 4780000
# Inserted 10000 records. Total records inserted: 4790000
# Inserted 10000 records. Total records inserted: 4800000
# Inserted 10000 records. Total records inserted: 4810000
# Inserted 10000 records. Total records inserted: 4820000
# Inserted 10000 records. Total records inserted: 4830000
# Inserted 10000 records. Total records inserted: 4840000
# Inserted 10000 records. Total records inserted: 4850000
# Inserted 10000 records. Total records inserted: 4860000
# Inserted 10000 records. Total records inserted: 4870000
# Inserted 10000 records. Total records inserted: 4880000
# Inserted 10000 records. Total records inserted: 4890000
# Inserted 10000 records. Total records inserted: 4900000
# Inserted 10000 records. Total records inserted: 4910000
# Inserted 10000 records. Total records inserted: 4920000
# Inserted 10000 records. Total records inserted: 4930000
# Inserted 10000 records. Total records inserted: 4940000
# Inserted 10000 records. Total records inserted: 4950000
# Inserted 10000 records. Total records inserted: 4960000
# Inserted 10000 records. Total records inserted: 4970000
# Inserted 10000 records. Total records inserted: 4980000
# Inserted 10000 records. Total records inserted: 4990000
# Inserted 10000 records. Total records inserted: 5000000
# Inserted 10000 records. Total records inserted: 5010000
# Inserted 10000 records. Total records inserted: 5020000
# Inserted 10000 records. Total records inserted: 5030000
# Inserted 10000 records. Total records inserted: 5040000
# Inserted 10000 records. Total records inserted: 5050000
# Inserted 10000 records. Total records inserted: 5060000
# Inserted 10000 records. Total records inserted: 5070000
# Inserted 10000 records. Total records inserted: 5080000
# Inserted 10000 records. Total records inserted: 5090000
# Inserted 10000 records. Total records inserted: 5100000
# Inserted 10000 records. Total records inserted: 5110000
# Inserted 10000 records. Total records inserted: 5120000
# Inserted 10000 records. Total records inserted: 5130000
# Inserted 10000 records. Total records inserted: 5140000
# Inserted 10000 records. Total records inserted: 5150000
# Inserted 10000 records. Total records inserted: 5160000
# Inserted 10000 records. Total records inserted: 5170000
# Inserted 10000 records. Total records inserted: 5180000
# Inserted 10000 records. Total records inserted: 5190000
# Inserted 10000 records. Total records inserted: 5200000
# Inserted 10000 records. Total records inserted: 5210000
# Inserted 10000 records. Total records inserted: 5220000
# Inserted 10000 records. Total records inserted: 5230000
# Inserted 10000 records. Total records inserted: 5240000
# Inserted 10000 records. Total records inserted: 5250000
# Inserted 10000 records. Total records inserted: 5260000
# Inserted 10000 records. Total records inserted: 5270000
# Inserted 10000 records. Total records inserted: 5280000
# Inserted 10000 records. Total records inserted: 5290000
# Inserted 10000 records. Total records inserted: 5300000
# Inserted 10000 records. Total records inserted: 5310000
# Inserted 10000 records. Total records inserted: 5320000
# Inserted 10000 records. Total records inserted: 5330000
# Inserted 10000 records. Total records inserted: 5340000
# Inserted 10000 records. Total records inserted: 5350000
# Inserted 10000 records. Total records inserted: 5360000
# Inserted 10000 records. Total records inserted: 5370000
# Inserted 10000 records. Total records inserted: 5380000
# Inserted 10000 records. Total records inserted: 5390000
# Inserted 10000 records. Total records inserted: 5400000
# Inserted 10000 records. Total records inserted: 5410000
# Inserted 10000 records. Total records inserted: 5420000
# Inserted 10000 records. Total records inserted: 5430000
# Inserted 10000 records. Total records inserted: 5440000
# Inserted 10000 records. Total records inserted: 5450000
# Inserted 10000 records. Total records inserted: 5460000
# Inserted 10000 records. Total records inserted: 5470000
# Inserted 10000 records. Total records inserted: 5480000
# Inserted 10000 records. Total records inserted: 5490000
# Inserted 10000 records. Total records inserted: 5500000
# Inserted 10000 records. Total records inserted: 5510000
# Inserted 10000 records. Total records inserted: 5520000
# Inserted 10000 records. Total records inserted: 5530000
# Inserted 10000 records. Total records inserted: 5540000
# Inserted 10000 records. Total records inserted: 5550000
# Inserted 10000 records. Total records inserted: 5560000
# Inserted 10000 records. Total records inserted: 5570000
# Inserted 10000 records. Total records inserted: 5580000
# Inserted 10000 records. Total records inserted: 5590000
# Inserted 10000 records. Total records inserted: 5600000
# Inserted 10000 records. Total records inserted: 5610000
# Inserted 10000 records. Total records inserted: 5620000
# Inserted 10000 records. Total records inserted: 5630000
# Inserted 10000 records. Total records inserted: 5640000
# Inserted 10000 records. Total records inserted: 5650000
# Inserted 10000 records. Total records inserted: 5660000
# Inserted 10000 records. Total records inserted: 5670000
# Inserted 10000 records. Total records inserted: 5680000
# Inserted 10000 records. Total records inserted: 5690000
# Inserted 10000 records. Total records inserted: 5700000
# Inserted 10000 records. Total records inserted: 5710000
# Inserted 10000 records. Total records inserted: 5720000
# Inserted 10000 records. Total records inserted: 5730000
# Inserted 10000 records. Total records inserted: 5740000
# Inserted 10000 records. Total records inserted: 5750000
# Inserted 10000 records. Total records inserted: 5760000
# Inserted 10000 records. Total records inserted: 5770000
# Inserted 10000 records. Total records inserted: 5780000
# Inserted 10000 records. Total records inserted: 5790000
# Inserted 10000 records. Total records inserted: 5800000
# Inserted 10000 records. Total records inserted: 5810000
# Inserted 10000 records. Total records inserted: 5820000
# Inserted 10000 records. Total records inserted: 5830000
# Inserted 10000 records. Total records inserted: 5840000
# Inserted 10000 records. Total records inserted: 5850000
# Inserted 10000 records. Total records inserted: 5860000
# Inserted 10000 records. Total records inserted: 5870000
# Inserted 10000 records. Total records inserted: 5880000
# Inserted 10000 records. Total records inserted: 5890000
# Inserted 10000 records. Total records inserted: 5900000
# Inserted 10000 records. Total records inserted: 5910000
# Inserted 10000 records. Total records inserted: 5920000
# Inserted 10000 records. Total records inserted: 5930000
# Inserted 10000 records. Total records inserted: 5940000
# Inserted 10000 records. Total records inserted: 5950000
# Inserted 10000 records. Total records inserted: 5960000
# Inserted 10000 records. Total records inserted: 5970000
# Inserted 10000 records. Total records inserted: 5980000
# Inserted 10000 records. Total records inserted: 5990000
# Inserted 10000 records. Total records inserted: 6000000
# Inserted 10000 records. Total records inserted: 6010000
# Inserted 10000 records. Total records inserted: 6020000
# Inserted 10000 records. Total records inserted: 6030000
# Inserted 10000 records. Total records inserted: 6040000
# Inserted 10000 records. Total records inserted: 6050000
# Inserted 10000 records. Total records inserted: 6060000
# Inserted 10000 records. Total records inserted: 6070000
# Inserted 10000 records. Total records inserted: 6080000
# Inserted 10000 records. Total records inserted: 6090000
# Inserted 10000 records. Total records inserted: 6100000
# Inserted 10000 records. Total records inserted: 6110000
# Inserted 10000 records. Total records inserted: 6120000
# Inserted 10000 records. Total records inserted: 6130000
# Inserted 10000 records. Total records inserted: 6140000
# Inserted 10000 records. Total records inserted: 6150000
# Inserted 10000 records. Total records inserted: 6160000
# Inserted 10000 records. Total records inserted: 6170000
# Inserted 10000 records. Total records inserted: 6180000
# Inserted 10000 records. Total records inserted: 6190000
# Inserted 10000 records. Total records inserted: 6200000
# Inserted 10000 records. Total records inserted: 6210000
# Inserted 10000 records. Total records inserted: 6220000
# Inserted 10000 records. Total records inserted: 6230000
# Inserted 10000 records. Total records inserted: 6240000
# Inserted 10000 records. Total records inserted: 6250000
# Inserted 10000 records. Total records inserted: 6260000
# Inserted 10000 records. Total records inserted: 6270000
# Inserted 10000 records. Total records inserted: 6280000
# Inserted 10000 records. Total records inserted: 6290000
# Inserted 10000 records. Total records inserted: 6300000
# Inserted 10000 records. Total records inserted: 6310000
# Inserted 10000 records. Total records inserted: 6320000
# Inserted 10000 records. Total records inserted: 6330000
# Inserted 10000 records. Total records inserted: 6340000
# Inserted 10000 records. Total records inserted: 6350000
# Inserted 10000 records. Total records inserted: 6360000
# Inserted 10000 records. Total records inserted: 6370000
# Inserted 10000 records. Total records inserted: 6380000
# Inserted 10000 records. Total records inserted: 6390000
# Inserted 10000 records. Total records inserted: 6400000
# Inserted 10000 records. Total records inserted: 6410000
# Inserted 10000 records. Total records inserted: 6420000
# Inserted 10000 records. Total records inserted: 6430000
# Inserted 10000 records. Total records inserted: 6440000
# Inserted 10000 records. Total records inserted: 6450000
# Inserted 10000 records. Total records inserted: 6460000
# Inserted 10000 records. Total records inserted: 6470000
# Inserted 10000 records. Total records inserted: 6480000
# Inserted 10000 records. Total records inserted: 6490000
# Inserted 10000 records. Total records inserted: 6500000
# Inserted 10000 records. Total records inserted: 6510000
# Inserted 10000 records. Total records inserted: 6520000
# Inserted 10000 records. Total records inserted: 6530000
# Inserted 10000 records. Total records inserted: 6540000
# Inserted 10000 records. Total records inserted: 6550000
# Inserted 10000 records. Total records inserted: 6560000
# Inserted 10000 records. Total records inserted: 6570000
# Inserted 10000 records. Total records inserted: 6580000
# Inserted 10000 records. Total records inserted: 6590000
# Inserted 10000 records. Total records inserted: 6600000
# Inserted 10000 records. Total records inserted: 6610000
# Inserted 10000 records. Total records inserted: 6620000
# Inserted 10000 records. Total records inserted: 6630000
# Inserted 10000 records. Total records inserted: 6640000
# Inserted 10000 records. Total records inserted: 6650000
# Inserted 10000 records. Total records inserted: 6660000
# Inserted 10000 records. Total records inserted: 6670000
# Inserted 10000 records. Total records inserted: 6680000
# Inserted 10000 records. Total records inserted: 6690000
# Inserted 10000 records. Total records inserted: 6700000
# Inserted 10000 records. Total records inserted: 6710000
# Inserted 10000 records. Total records inserted: 6720000
# Inserted 10000 records. Total records inserted: 6730000
# Inserted 10000 records. Total records inserted: 6740000
# Inserted 10000 records. Total records inserted: 6750000
# Inserted 10000 records. Total records inserted: 6760000
# Inserted 10000 records. Total records inserted: 6770000
# Inserted 10000 records. Total records inserted: 6780000
# Inserted 10000 records. Total records inserted: 6790000
# Inserted 10000 records. Total records inserted: 6800000
# Inserted 10000 records. Total records inserted: 6810000
# Inserted 10000 records. Total records inserted: 6820000
# Inserted 10000 records. Total records inserted: 6830000
# Inserted 10000 records. Total records inserted: 6840000
# Inserted 10000 records. Total records inserted: 6850000
# Inserted 10000 records. Total records inserted: 6860000
# Inserted 10000 records. Total records inserted: 6870000
# Inserted 10000 records. Total records inserted: 6880000
# Inserted 10000 records. Total records inserted: 6890000
# Inserted 10000 records. Total records inserted: 6900000
# Inserted 10000 records. Total records inserted: 6910000
# Inserted 10000 records. Total records inserted: 6920000
# Inserted 10000 records. Total records inserted: 6930000
# Inserted 10000 records. Total records inserted: 6940000
# Inserted 10000 records. Total records inserted: 6950000
# Inserted 10000 records. Total records inserted: 6960000
# Inserted 10000 records. Total records inserted: 6970000
# Inserted 10000 records. Total records inserted: 6980000
# Inserted 10000 records. Total records inserted: 6990000
# Inserted 10000 records. Total records inserted: 7000000
# Inserted 10000 records. Total records inserted: 7010000
# Inserted 10000 records. Total records inserted: 7020000
# Inserted 10000 records. Total records inserted: 7030000
# Inserted 10000 records. Total records inserted: 7040000
# Inserted 10000 records. Total records inserted: 7050000
# Inserted 10000 records. Total records inserted: 7060000
# Inserted 10000 records. Total records inserted: 7070000
# Inserted 10000 records. Total records inserted: 7080000
# Inserted 10000 records. Total records inserted: 7090000
# Inserted 10000 records. Total records inserted: 7100000
# Inserted 10000 records. Total records inserted: 7110000
# Inserted 10000 records. Total records inserted: 7120000
# Inserted 10000 records. Total records inserted: 7130000
# Inserted 10000 records. Total records inserted: 7140000
# Inserted 10000 records. Total records inserted: 7150000
# Inserted 10000 records. Total records inserted: 7160000
# Inserted 10000 records. Total records inserted: 7170000
# Inserted 10000 records. Total records inserted: 7180000
# Inserted 10000 records. Total records inserted: 7190000
# Inserted 10000 records. Total records inserted: 7200000
# Inserted 10000 records. Total records inserted: 7210000
# Inserted 10000 records. Total records inserted: 7220000
# Inserted 10000 records. Total records inserted: 7230000
# Inserted 10000 records. Total records inserted: 7240000
# Inserted 10000 records. Total records inserted: 7250000
# Inserted 10000 records. Total records inserted: 7260000
# Inserted 10000 records. Total records inserted: 7270000
# Inserted 10000 records. Total records inserted: 7280000
# Inserted 10000 records. Total records inserted: 7290000
# Inserted 10000 records. Total records inserted: 7300000
# Inserted 10000 records. Total records inserted: 7310000
# Inserted 10000 records. Total records inserted: 7320000
# Inserted 10000 records. Total records inserted: 7330000
# Inserted 10000 records. Total records inserted: 7340000
# Inserted 10000 records. Total records inserted: 7350000
# Inserted 10000 records. Total records inserted: 7360000
# Inserted 10000 records. Total records inserted: 7370000
# Inserted 10000 records. Total records inserted: 7380000
# Inserted 10000 records. Total records inserted: 7390000
# Inserted 10000 records. Total records inserted: 7400000
# Inserted 10000 records. Total records inserted: 7410000
# Inserted 10000 records. Total records inserted: 7420000
# Inserted 10000 records. Total records inserted: 7430000
# Inserted 10000 records. Total records inserted: 7440000
# Inserted 10000 records. Total records inserted: 7450000
# Inserted 10000 records. Total records inserted: 7460000
# Inserted 10000 records. Total records inserted: 7470000
# Inserted 10000 records. Total records inserted: 7480000
# Inserted 10000 records. Total records inserted: 7490000
# Inserted 10000 records. Total records inserted: 7500000
# Inserted 10000 records. Total records inserted: 7510000
# Inserted 10000 records. Total records inserted: 7520000
# Inserted 10000 records. Total records inserted: 7530000
# Inserted 10000 records. Total records inserted: 7540000
# Inserted 10000 records. Total records inserted: 7550000
# Inserted 10000 records. Total records inserted: 7560000
# Inserted 10000 records. Total records inserted: 7570000
# Inserted 10000 records. Total records inserted: 7580000
# Inserted 10000 records. Total records inserted: 7590000
# Inserted 10000 records. Total records inserted: 7600000
# Inserted 10000 records. Total records inserted: 7610000
# Inserted 10000 records. Total records inserted: 7620000
# Inserted 10000 records. Total records inserted: 7630000
# Inserted 10000 records. Total records inserted: 7640000
# Inserted 10000 records. Total records inserted: 7650000
# Inserted 10000 records. Total records inserted: 7660000
# Inserted 10000 records. Total records inserted: 7670000
# Inserted 10000 records. Total records inserted: 7680000
# Inserted 10000 records. Total records inserted: 7690000
# Inserted 10000 records. Total records inserted: 7700000
# Inserted 10000 records. Total records inserted: 7710000
# Inserted 10000 records. Total records inserted: 7720000
# Inserted 10000 records. Total records inserted: 7730000
# Inserted 10000 records. Total records inserted: 7740000
# Inserted 10000 records. Total records inserted: 7750000
# Inserted 10000 records. Total records inserted: 7760000
# Inserted 10000 records. Total records inserted: 7770000
# Inserted 10000 records. Total records inserted: 7780000
# Inserted 10000 records. Total records inserted: 7790000
# Inserted 10000 records. Total records inserted: 7800000
# Inserted 10000 records. Total records inserted: 7810000
# Inserted 10000 records. Total records inserted: 7820000
# Inserted 10000 records. Total records inserted: 7830000
# Inserted 10000 records. Total records inserted: 7840000
# Inserted 10000 records. Total records inserted: 7850000
# Inserted 10000 records. Total records inserted: 7860000
# Inserted 10000 records. Total records inserted: 7870000
# Inserted 10000 records. Total records inserted: 7880000
# Inserted 10000 records. Total records inserted: 7890000
# Inserted 10000 records. Total records inserted: 7900000
# Inserted 10000 records. Total records inserted: 7910000
# Inserted 10000 records. Total records inserted: 7920000
# Inserted 10000 records. Total records inserted: 7930000
# Inserted 10000 records. Total records inserted: 7940000
# Inserted 10000 records. Total records inserted: 7950000
# Inserted 10000 records. Total records inserted: 7960000
# Inserted 10000 records. Total records inserted: 7970000
# Inserted 10000 records. Total records inserted: 7980000
# Inserted 10000 records. Total records inserted: 7990000
# Inserted 10000 records. Total records inserted: 8000000
# Inserted 10000 records. Total records inserted: 8010000
# Inserted 10000 records. Total records inserted: 8020000
# Inserted 10000 records. Total records inserted: 8030000
# Inserted 10000 records. Total records inserted: 8040000
# Inserted 10000 records. Total records inserted: 8050000
# Inserted 10000 records. Total records inserted: 8060000
# Inserted 10000 records. Total records inserted: 8070000
# Inserted 10000 records. Total records inserted: 8080000
# Inserted 10000 records. Total records inserted: 8090000
# Inserted 10000 records. Total records inserted: 8100000
# Inserted 10000 records. Total records inserted: 8110000
# Inserted 10000 records. Total records inserted: 8120000
# Inserted 10000 records. Total records inserted: 8130000
# Inserted 10000 records. Total records inserted: 8140000
# Inserted 10000 records. Total records inserted: 8150000
# Inserted 10000 records. Total records inserted: 8160000
# Inserted 10000 records. Total records inserted: 8170000
# Inserted 10000 records. Total records inserted: 8180000
# Inserted 10000 records. Total records inserted: 8190000
# Inserted 10000 records. Total records inserted: 8200000
# Inserted 10000 records. Total records inserted: 8210000
# Inserted 10000 records. Total records inserted: 8220000
# Inserted 10000 records. Total records inserted: 8230000
# Inserted 10000 records. Total records inserted: 8240000
# Inserted 10000 records. Total records inserted: 8250000
# Inserted 10000 records. Total records inserted: 8260000
# Inserted 10000 records. Total records inserted: 8270000
# Inserted 10000 records. Total records inserted: 8280000
# Inserted 10000 records. Total records inserted: 8290000
# Inserted 10000 records. Total records inserted: 8300000
# Inserted 10000 records. Total records inserted: 8310000
# Inserted 10000 records. Total records inserted: 8320000
# Inserted 10000 records. Total records inserted: 8330000
# Inserted 10000 records. Total records inserted: 8340000
# Inserted 10000 records. Total records inserted: 8350000
# Inserted 10000 records. Total records inserted: 8360000
# Inserted 10000 records. Total records inserted: 8370000
# Inserted 10000 records. Total records inserted: 8380000
# Inserted 10000 records. Total records inserted: 8390000
# Inserted 10000 records. Total records inserted: 8400000
# Inserted 10000 records. Total records inserted: 8410000
# Inserted 10000 records. Total records inserted: 8420000
# Inserted 10000 records. Total records inserted: 8430000
# Inserted 10000 records. Total records inserted: 8440000
# Inserted 10000 records. Total records inserted: 8450000
# Inserted 10000 records. Total records inserted: 8460000
# Inserted 10000 records. Total records inserted: 8470000
# Inserted 10000 records. Total records inserted: 8480000
# Inserted 10000 records. Total records inserted: 8490000
# Inserted 10000 records. Total records inserted: 8500000
# Inserted 10000 records. Total records inserted: 8510000
# Inserted 10000 records. Total records inserted: 8520000
# Inserted 10000 records. Total records inserted: 8530000
# Inserted 10000 records. Total records inserted: 8540000
# Inserted 10000 records. Total records inserted: 8550000
# Inserted 10000 records. Total records inserted: 8560000
# Inserted 10000 records. Total records inserted: 8570000
# Inserted 10000 records. Total records inserted: 8580000
# Inserted 10000 records. Total records inserted: 8590000
# ...
# Inserted 10000 records. Total records inserted: 17210000
# Inserted 10000 records. Total records inserted: 17220000
# Inserted 10000 records. Total records inserted: 17230000
# Inserted 10000 records. Total records inserted: 17240000
# Inserted 10000 records. Total records inserted: 17250000
# Inserted 10000 records. Total records inserted: 17260000
# Inserted 10000 records. Total records inserted: 17270000
# Inserted 10000 records. Total records inserted: 17280000
# Inserted 10000 records. Total records inserted: 17290000
# Inserted 10000 records. Total records inserted: 17300000
# Inserted 10000 records. Total records inserted: 17310000
# Inserted 10000 records. Total records inserted: 17320000
# Inserted 10000 records. Total records inserted: 17330000
# Inserted 10000 records. Total records inserted: 17340000
# Inserted 10000 records. Total records inserted: 17350000
# Inserted 10000 records. Total records inserted: 17360000
# Inserted 10000 records. Total records inserted: 17370000
# Inserted 10000 records. Total records inserted: 17380000
# Inserted 10000 records. Total records inserted: 17390000
# Inserted 10000 records. Total records inserted: 17400000
# Inserted 10000 records. Total records inserted: 17410000
# Inserted 10000 records. Total records inserted: 17420000
# Inserted 10000 records. Total records inserted: 17430000
# Inserted 10000 records. Total records inserted: 17440000
# Inserted 10000 records. Total records inserted: 17450000
# Inserted 10000 records. Total records inserted: 17460000
# Inserted 10000 records. Total records inserted: 17470000
# Inserted 10000 records. Total records inserted: 17480000
# Inserted 10000 records. Total records inserted: 17490000
# Inserted 10000 records. Total records inserted: 17500000
# Inserted 10000 records. Total records inserted: 17510000
# Inserted 10000 records. Total records inserted: 17520000
# Inserted 10000 records. Total records inserted: 17530000
# Inserted 10000 records. Total records inserted: 17540000
# Inserted 10000 records. Total records inserted: 17550000
# Inserted 10000 records. Total records inserted: 17560000
# Inserted 10000 records. Total records inserted: 17570000
# Inserted 10000 records. Total records inserted: 17580000
# Inserted 10000 records. Total records inserted: 17590000
# Inserted 10000 records. Total records inserted: 17600000
# Inserted 10000 records. Total records inserted: 17610000
# Inserted 10000 records. Total records inserted: 17620000
# Inserted 10000 records. Total records inserted: 17630000
# Inserted 10000 records. Total records inserted: 17640000
# Inserted 10000 records. Total records inserted: 17650000
# Inserted 10000 records. Total records inserted: 17660000
# Inserted 10000 records. Total records inserted: 17670000
# Inserted 10000 records. Total records inserted: 17680000
# Inserted 10000 records. Total records inserted: 17690000
# Inserted 10000 records. Total records inserted: 17700000
# Inserted 10000 records. Total records inserted: 17710000
# Inserted 10000 records. Total records inserted: 17720000
# Inserted 10000 records. Total records inserted: 17730000
# Inserted 10000 records. Total records inserted: 17740000
# Inserted 10000 records. Total records inserted: 17750000
# Inserted 10000 records. Total records inserted: 17760000
# Inserted 10000 records. Total records inserted: 17770000
# Inserted 10000 records. Total records inserted: 17780000
# Inserted 10000 records. Total records inserted: 17790000
# Inserted 10000 records. Total records inserted: 17800000
# Inserted 10000 records. Total records inserted: 17810000
# Inserted 10000 records. Total records inserted: 17820000
# Inserted 10000 records. Total records inserted: 17830000
# Inserted 10000 records. Total records inserted: 17840000
# Inserted 10000 records. Total records inserted: 17850000
# Inserted 10000 records. Total records inserted: 17860000
# Inserted 10000 records. Total records inserted: 17870000
# Inserted 10000 records. Total records inserted: 17880000
# Inserted 10000 records. Total records inserted: 17890000
# Inserted 10000 records. Total records inserted: 17900000
# Inserted 10000 records. Total records inserted: 17910000
# Inserted 10000 records. Total records inserted: 17920000
# Inserted 10000 records. Total records inserted: 17930000
# Inserted 10000 records. Total records inserted: 17940000
# Inserted 10000 records. Total records inserted: 17950000
# Inserted 10000 records. Total records inserted: 17960000
# Inserted 10000 records. Total records inserted: 17970000
# Inserted 10000 records. Total records inserted: 17980000
# Inserted 10000 records. Total records inserted: 17990000
# Inserted 10000 records. Total records inserted: 18000000
# Inserted 10000 records. Total records inserted: 18010000
# Inserted 10000 records. Total records inserted: 18020000
# Inserted 10000 records. Total records inserted: 18030000
# Inserted 10000 records. Total records inserted: 18040000
# Inserted 10000 records. Total records inserted: 18050000
# Inserted 10000 records. Total records inserted: 18060000
# Inserted 10000 records. Total records inserted: 18070000
# Inserted 10000 records. Total records inserted: 18080000
# Inserted 10000 records. Total records inserted: 18090000
# Inserted 10000 records. Total records inserted: 18100000
# Inserted 10000 records. Total records inserted: 18110000
# Inserted 10000 records. Total records inserted: 18120000
# Inserted 10000 records. Total records inserted: 18130000
# Inserted 10000 records. Total records inserted: 18140000
# Inserted 10000 records. Total records inserted: 18150000
# Inserted 10000 records. Total records inserted: 18160000
# Inserted 10000 records. Total records inserted: 18170000
# Inserted 10000 records. Total records inserted: 18180000
# Inserted 10000 records. Total records inserted: 18190000
# Inserted 10000 records. Total records inserted: 18200000
# Inserted 10000 records. Total records inserted: 18210000
# Inserted 10000 records. Total records inserted: 18220000
# Inserted 10000 records. Total records inserted: 18230000
# Inserted 10000 records. Total records inserted: 18240000
# Inserted 10000 records. Total records inserted: 18250000
# Inserted 10000 records. Total records inserted: 18260000
# Inserted 10000 records. Total records inserted: 18270000
# Inserted 10000 records. Total records inserted: 18280000
# Inserted 10000 records. Total records inserted: 18290000
# Inserted 10000 records. Total records inserted: 18300000
# Inserted 10000 records. Total records inserted: 18310000
# Inserted 10000 records. Total records inserted: 18320000
# Inserted 10000 records. Total records inserted: 18330000
# Inserted 10000 records. Total records inserted: 18340000
# Inserted 10000 records. Total records inserted: 18350000
# Inserted 10000 records. Total records inserted: 18360000
# Inserted 10000 records. Total records inserted: 18370000
# Inserted 10000 records. Total records inserted: 18380000
# Inserted 10000 records. Total records inserted: 18390000
# Inserted 10000 records. Total records inserted: 18400000
# Inserted 10000 records. Total records inserted: 18410000
# Inserted 10000 records. Total records inserted: 18420000
# Inserted 10000 records. Total records inserted: 18430000
# Inserted 10000 records. Total records inserted: 18440000
# Inserted 10000 records. Total records inserted: 18450000
# Inserted 10000 records. Total records inserted: 18460000
# Inserted 10000 records. Total records inserted: 18470000
# Inserted 10000 records. Total records inserted: 18480000
# Inserted 10000 records. Total records inserted: 18490000
# Inserted 10000 records. Total records inserted: 18500000
# Inserted 10000 records. Total records inserted: 18510000
# Inserted 10000 records. Total records inserted: 18520000
# Inserted 10000 records. Total records inserted: 18530000
# Inserted 10000 records. Total records inserted: 18540000
# Inserted 10000 records. Total records inserted: 18550000
# Inserted 10000 records. Total records inserted: 18560000
# Inserted 10000 records. Total records inserted: 18570000
# Inserted 10000 records. Total records inserted: 18580000
# Inserted 10000 records. Total records inserted: 18590000
# Inserted 10000 records. Total records inserted: 18600000
# Inserted 10000 records. Total records inserted: 18610000
# Inserted 10000 records. Total records inserted: 18620000
# Inserted 10000 records. Total records inserted: 18630000
# Inserted 10000 records. Total records inserted: 18640000
# Inserted 10000 records. Total records inserted: 18650000
# Inserted 10000 records. Total records inserted: 18660000
# Inserted 10000 records. Total records inserted: 18670000
# Inserted 10000 records. Total records inserted: 18680000
# Inserted 10000 records. Total records inserted: 18690000
# Inserted 10000 records. Total records inserted: 18700000
# Inserted 10000 records. Total records inserted: 18710000
# Inserted 10000 records. Total records inserted: 18720000
# Inserted 10000 records. Total records inserted: 18730000
# Inserted 10000 records. Total records inserted: 18740000
# Inserted 10000 records. Total records inserted: 18750000
# Inserted 10000 records. Total records inserted: 18760000
# Inserted 10000 records. Total records inserted: 18770000
# Inserted 10000 records. Total records inserted: 18780000
# Inserted 10000 records. Total records inserted: 18790000
# Inserted 10000 records. Total records inserted: 18800000
# Inserted 10000 records. Total records inserted: 18810000
# Inserted 10000 records. Total records inserted: 18820000
# Inserted 10000 records. Total records inserted: 18830000
# Inserted 10000 records. Total records inserted: 18840000
# Inserted 10000 records. Total records inserted: 18850000
# Inserted 10000 records. Total records inserted: 18860000
# Inserted 10000 records. Total records inserted: 18870000
# Inserted 10000 records. Total records inserted: 18880000
# Inserted 10000 records. Total records inserted: 18890000
# Inserted 10000 records. Total records inserted: 18900000
# Inserted 10000 records. Total records inserted: 18910000
# Inserted 10000 records. Total records inserted: 18920000
# Inserted 10000 records. Total records inserted: 18930000
# Inserted 10000 records. Total records inserted: 18940000
# Inserted 10000 records. Total records inserted: 18950000
# Inserted 10000 records. Total records inserted: 18960000
# Inserted 10000 records. Total records inserted: 18970000
# Inserted 10000 records. Total records inserted: 18980000
# Inserted 10000 records. Total records inserted: 18990000
# Inserted 10000 records. Total records inserted: 19000000
# Inserted 10000 records. Total records inserted: 19010000
# Inserted 10000 records. Total records inserted: 19020000
# Inserted 10000 records. Total records inserted: 19030000
# Inserted 10000 records. Total records inserted: 19040000
# Inserted 10000 records. Total records inserted: 19050000
# Inserted 10000 records. Total records inserted: 19060000
# Inserted 10000 records. Total records inserted: 19070000
# Inserted 10000 records. Total records inserted: 19080000
# Inserted 10000 records. Total records inserted: 19090000
# Inserted 10000 records. Total records inserted: 19100000
# Inserted 10000 records. Total records inserted: 19110000
# Inserted 10000 records. Total records inserted: 19120000
# Inserted 10000 records. Total records inserted: 19130000
# Inserted 10000 records. Total records inserted: 19140000
# Inserted 10000 records. Total records inserted: 19150000
# Inserted 10000 records. Total records inserted: 19160000
# Inserted 10000 records. Total records inserted: 19170000
# Inserted 10000 records. Total records inserted: 19180000
# Inserted 10000 records. Total records inserted: 19190000
# Inserted 10000 records. Total records inserted: 19200000
# Inserted 10000 records. Total records inserted: 19210000
# Inserted 10000 records. Total records inserted: 19220000
# Inserted 10000 records. Total records inserted: 19230000
# Inserted 10000 records. Total records inserted: 19240000
# Inserted 10000 records. Total records inserted: 19250000
# Inserted 10000 records. Total records inserted: 19260000
# Inserted 10000 records. Total records inserted: 19270000
# Inserted 10000 records. Total records inserted: 19280000
# Inserted 10000 records. Total records inserted: 19290000
# Inserted 10000 records. Total records inserted: 19300000
# Inserted 10000 records. Total records inserted: 19310000
# Inserted 10000 records. Total records inserted: 19320000
# Inserted 10000 records. Total records inserted: 19330000
# Inserted 10000 records. Total records inserted: 19340000
# Inserted 10000 records. Total records inserted: 19350000
# Inserted 10000 records. Total records inserted: 19360000
# Inserted 10000 records. Total records inserted: 19370000
# Inserted 10000 records. Total records inserted: 19380000
# Inserted 10000 records. Total records inserted: 19390000
# Inserted 10000 records. Total records inserted: 19400000
# Inserted 10000 records. Total records inserted: 19410000
# Inserted 10000 records. Total records inserted: 19420000
# Inserted 10000 records. Total records inserted: 19430000
# Inserted 10000 records. Total records inserted: 19440000
# Inserted 10000 records. Total records inserted: 19450000
# Inserted 10000 records. Total records inserted: 19460000
# Inserted 10000 records. Total records inserted: 19470000
# Inserted 10000 records. Total records inserted: 19480000
# Inserted 10000 records. Total records inserted: 19490000
# Inserted 10000 records. Total records inserted: 19500000
# Inserted 10000 records. Total records inserted: 19510000
# Inserted 10000 records. Total records inserted: 19520000
# Inserted 10000 records. Total records inserted: 19530000
# Inserted 10000 records. Total records inserted: 19540000
# Inserted 10000 records. Total records inserted: 19550000
# Inserted 10000 records. Total records inserted: 19560000
# Inserted 10000 records. Total records inserted: 19570000
# Inserted 10000 records. Total records inserted: 19580000
# Inserted 10000 records. Total records inserted: 19590000
# Inserted 10000 records. Total records inserted: 19600000
# Inserted 10000 records. Total records inserted: 19610000
# Inserted 10000 records. Total records inserted: 19620000
# Inserted 10000 records. Total records inserted: 19630000
# Inserted 10000 records. Total records inserted: 19640000
# Inserted 10000 records. Total records inserted: 19650000
# Inserted 10000 records. Total records inserted: 19660000
# Inserted 10000 records. Total records inserted: 19670000
# Inserted 10000 records. Total records inserted: 19680000
# Inserted 10000 records. Total records inserted: 19690000
# Inserted 10000 records. Total records inserted: 19700000
# Inserted 10000 records. Total records inserted: 19710000
# Inserted 10000 records. Total records inserted: 19720000
# Inserted 10000 records. Total records inserted: 19730000
# Inserted 10000 records. Total records inserted: 19740000
# Inserted 10000 records. Total records inserted: 19750000
# Inserted 10000 records. Total records inserted: 19760000
# Inserted 10000 records. Total records inserted: 19770000
# Inserted 10000 records. Total records inserted: 19780000
# Inserted 10000 records. Total records inserted: 19790000
# Inserted 10000 records. Total records inserted: 19800000
# Inserted 10000 records. Total records inserted: 19810000
# Inserted 10000 records. Total records inserted: 19820000
# Inserted 10000 records. Total records inserted: 19830000
# Inserted 10000 records. Total records inserted: 19840000
# Inserted 10000 records. Total records inserted: 19850000
# Inserted 10000 records. Total records inserted: 19860000
# Inserted 10000 records. Total records inserted: 19870000
# Inserted 10000 records. Total records inserted: 19880000
# Inserted 10000 records. Total records inserted: 19890000
# Inserted 10000 records. Total records inserted: 19900000
# Inserted 10000 records. Total records inserted: 19910000
# Inserted 10000 records. Total records inserted: 19920000
# Inserted 10000 records. Total records inserted: 19930000
# Inserted 10000 records. Total records inserted: 19940000
# Inserted 10000 records. Total records inserted: 19950000
# Inserted 10000 records. Total records inserted: 19960000
# Inserted 10000 records. Total records inserted: 19970000
# Inserted 10000 records. Total records inserted: 19980000
# Inserted 10000 records. Total records inserted: 19990000
# Inserted 10000 records. Total records inserted: 20000000
# Insertion complete.

# %%
record = db.read_record_by_id(150000)
print(record)
# Out:
# {150000: {'id': 150001, 'embed': [0.3768047094345093, 0.5434426069259644, 0.6379473209381104, 0.09962593764066696, 0.0887569859623909, 0.7316314578056335, 0.5597277879714966, 0.5738756656646729, 0.8712009787559509, 0.4523925185203552, 0.9733819365501404, 0.5012685656547546, 0.6938456296920776, 0.4241641163825989, 0.6885622143745422, 0.1353963315486908, 0.8240202069282532, 0.9548629522323608, 0.9230455756187439, 0.24257425963878632, 0.5855097770690918, 0.767795979976654, 0.8740313649177551, 0.880972683429718, 0.44004979729652405, 0.8210075497627258, 0.32657867670059204, 0.1786700040102005, 0.3260217010974884, 0.5470225811004639, 0.5936652421951294, 0.583935022354126, 0.8334327340126038, 0.4611385464668274, 0.8981862664222717, 0.938395619392395, 0.4210079312324524, 0.1288173347711563, 0.03499150648713112, 0.9750182628631592, 0.19303089380264282, 0.9584629535675049, 0.32923057675361633, 0.3998655378818512, 0.405233234167099, 0.6883865594863892, 0.8930075764656067, 0.7664490938186646, 0.11327001452445984, 0.7160975337028503, 0.6382924914360046, 0.6965753436088562, 0.6184334754943848, 0.48209816217422485, 0.9646931886672974, 0.826825737953186, 0.8537719249725342, 0.11854895949363708, 0.9870730638504028, 0.9917011260986328, 0.8014813661575317, 0.2243438959121704, 0.8713148236274719, 0.9589816927909851, 0.7306884527206421, 0.5849587321281433, 0.2610810101032257, 0.08245505392551422, 0.82109534740448, 0.25531795620918274]}}

# %%
import numpy as np
#  generate arr tuple start from 0 to 20_000_000
arr = np.arange(0, 20000000, 1)
#  print size of arr
# Out:
# 20000000

# %%
with open('saved_db.csv', 'r') as file:
    # Move to the 10th byte from the beginning of the file
    file.seek(0)
    
    # Read and print the content from the current position
    # 1 MB => 1,000,000 bytes
    # 1,000,000 /1350 => 740
    # 20_000_000 / 740 => 27_027 blocks
    # content = file.read(1_000_000)
    content = file.readline()
    #  print the size of the line
    print(len(content))
    print(content)
    file.seek(len(content)+1)
    content = file.readline()
    print(len(content))
    print(content)
# Out:
# 1352
# 1,0.6606054344785669,0.44804264919028125,0.22881102975586143,0.05333096241749047,0.5084951022842068,0.24025468500905356,0.9004077931618367,0.5564744960563222,0.6457622553961205,0.4071379003772593,0.351361920884804,0.5246836622014442,0.5630821296710911,0.13841085114014862,0.912664767315102,0.5534151567197382,0.10338708210292058,0.3645633090119468,0.6404595199220359,0.5813346723340996,0.42199801042598284,0.10550608934237249,0.5526635969910976,0.43935910359837194,0.6732200053671904,0.7076701077422254,0.19089540924022919,0.9152535222406287,0.8863368914838918,0.9655744116760181,0.5840517776203855,0.7949553581999904,0.8518481739348143,0.6931905817377731,0.26893208995375584,0.5426920969546063,0.5658971300296081,0.5877407129287981,0.3977236524806921,0.6332123020053829,0.33207439505341196,0.8456863999150352,0.6296123820724633,0.22941054064612076,0.9236083251994747,0.08041007481992846,0.2645688410916386,0.5302248461883718,0.021245950392764446,0.40642113522284695,0.4509976122110796,0.4079103272609528,0.38330164542954837,0.725330355669261,0.6691236347883495,0.4661909585879509,0.028051436908156258,0.4061235868070294,0.2570159154328524,0.968525791124133,0.7227258279612139,0.38467004795327875,0.8212118142071577,0.03033475072823799,0.10586801880942065,0.5493969694426779,0.1746771312465809,0.011581852973229556,0.802827737044827,0.6963517422863184
#
# 1342
# 2,0.7777482693320314,0.3041059253446723,0.7849297227468245,0.8119526011045088,0.4590568204169747,0.16310490352628415,0.05947505602100556,0.5139295064546109,0.384642802766647,0.5149811901618657,0.8764004213694623,0.9269813194261639,0.5844374516674591,0.21364371415028693,0.9257767563109711,0.848165690015116,0.8103952445259176,0.2960872564865453,0.9957015404874499,0.10438002120171475,0.11115247567408293,0.6073956757718989,0.037121416521344264,0.20301238851691839,0.4266388405416971,0.45795858205367024,0.3073001405683219,0.5938384951428581,0.07312542565350721,0.775976461150876,0.9322401825205642,0.8889367500930058,0.5655133545499716,0.9940594594361349,0.3989475122499484,0.046811981843524975,0.3384456465509561,0.9544278536529925,0.7081063531016842,0.8703561105189421,0.25646270213634614,0.8751180300809858,0.5786544608232048,0.92149656356517,0.8154661786100234,0.4111803517139163,0.39867177026306244,0.8031402167881558,0.963585028000135,0.14436896796099452,0.6757438126186164,0.3117215601159602,0.48771651097657176,0.6874290239697484,0.174047611904393,0.3698535287309648,0.037335762898989766,0.3204398497161648,0.6994794491695989,0.306032550925157,0.4183888204489862,0.6394680776560338,0.11475189915035477,0.6196708172326141,0.351762048427387,0.6246525663585474,0.55281277010323,0.034803411951095486,0.5189817109692403,0.5581671812691505
