# %% [markdown]
# # This Notebook for Running the ADB Project Phase 2

# %% [markdown]
# **This notebook is divided into two main parts, each focusing on different database sizes:**
# - **Part 1: Database Size 10K**
#   - Initiate a new database and insert vectors into it.
#   - Retrieve vectors from the database.
#   - Ensure that the insertion time for this database does not exceed 5 minutes.
#   - Allow flexible RAM usage during insertion but ensure it stays within Google Colab limits.
#   - Evaluate retrieval time and accuracy.
#   - Ensure that the peak RAM usage for retrieval does not exceed 5 MB.
#
# - **Part 2: Database Sizes 100K and More**
#   - Generate database vectors using a random seed (refer to the provided code).
#   - You have generate the database and its index before the submission.
#   - Implement a VecDB class that loads the pre-generated database, including the index, and retrieves vectors, to load the generated database.
#   - Evaluate retrieval time and accuracy for different database sizes.
#   - The Peak RAM usage for the retrieval should not exceed
#     - For 100 K --> 10 MB
#     - For 1 M --> 25 MB
#     - For 5 M --> 75 MB
#     - For 10 M --> 150 MB
#     - For 15 M --> 225 MB
#     - For 20 M --> 300 MB
#
# **This notebook is structured into two parts:**
#
# - **Part 1 - Modifiable Cells:**
# This section contains cells that teams are allowed to modify. The modification are only variables and to be submitted during the project's final phase. They are
#   - GitHub repository link (including PAT token).
#   - Database (DB) variables, providing the path to the directory or file for loading existing databases and indexes (refer to provided code to see how).
#
# - **Part 2 - Non-Modifiable Cells:** This section must not be modified by any team. It includes essential setup and evaluation code. Ensure that the notebook runs smoothly by providing the required inputs in Part 1.

# %% [markdown]
# ## Part 1 - Modifiable Cells

# %% [markdown]
# Of course each team will provide different github repo link
# Should include PAT token to enable me to download

# %%
# !git clone https://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@github.com/ZiadSheriif/sematic_search_DB
# Out:
# Cloning into 'sematic_search_DB'...
# remote: Enumerating objects: 634, done.
# remote: Counting objects: 100% (128/128), done.
# remote: Compressing objects: 100% (86/86), done.
# remote: Total 634 (delta 79), reused 84 (delta 39), pack-reused 506
# Receiving objects: 100% (634/634), 3.26 MiB | 21.37 MiB/s, done.
# Resolving deltas: 100% (393/393), done.

# %% [markdown]
# Teams are required to provide unique paths for the generated databases of sizes 1M, 5M, 10M, 15M, and 20M. Follow these steps to submit the databases:
#
# - Once you have the database and index ready, zip the necessary folders/files.
# - Upload the zip file to Google Drive.
# - Ensure the file is shareable with "anyone with the link."
# - Obtain the zip file link (e.g., https://drive.google.com/file/d/1j1gAU3kvdRqcOoKI5K5FgMMUZpOQANah/view?usp=drive_link).
# - Extract the zip file ID (e.g., 1j1gAU3kvdRqcOoKI5K5FgMMUZpOQANah).
# - Place the ID in the designated variable (to be submitted during the project final phase).
# - The code will automatically download the zip file and unzip it inside this directory.
# - Provide the local PATH for each database to be passed to the initializer for automatic loading of the database and index (to be submitted during the project final phase).

# %%
TEAM_NUMBER = 9
GDRIVE_ID_DB_100K = "1-cXWAbGLVln8iM67iQLMHEpf2yIqZQjy"
GDRIVE_ID_DB_1M = "1-dFGlgkIy04-sl7N-5Wj5oKQRmXo2VXJ"
GDRIVE_ID_DB_5M = "1tHmURGUaDjrTnxDfkatPRGJYGdcoqAZH"
GDRIVE_ID_DB_10M = "161u5tFGlrgf2zc-nC2GbJkYcvSxI0Buj"
GDRIVE_ID_DB_15M = "1uVtt-EfFCLKyC5-h62datQDuXmk18vAu"
GDRIVE_ID_DB_20M = "1xUVW6vN48WNPHe8WqthZIgjqEbVbc6NM"
PATH_DB_100K = "./DataBase_100K"
PATH_DB_1M = "./DataBase_1M"
PATH_DB_5M = "./DataBase_5M"
PATH_DB_10M = "./DataBase_10M"
PATH_DB_15M = "./DataBase_15M"
PATH_DB_20M = "./DataBase_20M"

# %% [markdown]
# These two varaible I'll change while running in on the discussion

# %%
QUERY_SEED_NUMBER = 10
DB_SEED_NUMBER = 20

# %% [markdown]
# This means that the project submission will include these
# - TEAM_NUMBER
# - Github clone link
# - GDRIVE_ID_DB_100K
# - GDRIVE_ID_DB_1M
# - GDRIVE_ID_DB_5M
# - GDRIVE_ID_DB_10M
# - GDRIVE_ID_DB_15M
# - GDRIVE_ID_DB_20M
# - PATH_DB_100K
# - PATH_DB_1M
# - PATH_DB_5M
# - PATH_DB_10M
# - PATH_DB_15M
# - PATH_DB_20M <br>
# - And for sure the project document that describes what you did

# %% [markdown]
# ## Part 2: No edits from here
# #### You can't edit this part, and neither me.
# #### Note: Maybe I can edit if there is a major bug

# %%
# %cd sematic_search_DB
# Out:
# /content/sematic_search_DB/sematic_search_DB

# %% [markdown]
# This cell to run any additional requirement that your code need <br>

# %%
# !pip install memory-profiler >> log.txt
# !pip install -r requirements.txt

# %% [markdown]
# This cell to download the zip files and unzip them here.

# %%
# !gdown $GDRIVE_ID_DB_100K -O saved_db_100k.zip
# !gdown $GDRIVE_ID_DB_1M -O saved_db_1m.zip
# !gdown $GDRIVE_ID_DB_5M -O saved_db_5m.zip
# !gdown $GDRIVE_ID_DB_10M -O saved_db_10m.zip
# !gdown $GDRIVE_ID_DB_15M -O saved_db_15m.zip
# !gdown $GDRIVE_ID_DB_20M -O saved_db_20m.zip
# !unzip saved_db_100k.zip
# !unzip saved_db_1m.zip
# !unzip saved_db_5m.zip
# !unzip saved_db_10m.zip
# !unzip saved_db_15m.zip
# !unzip saved_db_20m.zip
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1-cXWAbGLVln8iM67iQLMHEpf2yIqZQjy
# To: /content/sematic_search_DB/sematic_search_DB/saved_db_100k.zip
# 100% 50.7M/50.7M [00:00<00:00, 61.8MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1-dFGlgkIy04-sl7N-5Wj5oKQRmXo2VXJ
# To: /content/sematic_search_DB/sematic_search_DB/saved_db_1m.zip
# 100% 507M/507M [00:06<00:00, 75.4MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1tHmURGUaDjrTnxDfkatPRGJYGdcoqAZH
# To: /content/sematic_search_DB/sematic_search_DB/saved_db_5m.zip
# 100% 2.54G/2.54G [00:38<00:00, 65.3MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=161u5tFGlrgf2zc-nC2GbJkYcvSxI0Buj
# To: /content/sematic_search_DB/sematic_search_DB/saved_db_10m.zip
# 100% 5.07G/5.07G [01:25<00:00, 59.5MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1uVtt-EfFCLKyC5-h62datQDuXmk18vAu
# To: /content/sematic_search_DB/sematic_search_DB/saved_db_15m.zip
# 100% 7.62G/7.62G [02:44<00:00, 46.3MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1xUVW6vN48WNPHe8WqthZIgjqEbVbc6NM
# To: /content/sematic_search_DB/sematic_search_DB/saved_db_20m.zip
# 100% 10.2G/10.2G [03:52<00:00, 43.8MB/s]
# Archive:  saved_db_100k.zip
#    creating: DataBase_100K/
#    creating: DataBase_100K/Level1/
#   inflating: DataBase_100K/Level1/centroids.bin
#   inflating: DataBase_100K/Level1/cluster0.bin
#   inflating: DataBase_100K/Level1/cluster1.bin
#   inflating: DataBase_100K/Level1/cluster2.bin
#   inflating: DataBase_100K/Level1/cluster3.bin
#   inflating: DataBase_100K/Level1/cluster4.bin
#   inflating: DataBase_100K/Level1/cluster5.bin
#   inflating: DataBase_100K/Level1/cluster6.bin
#   inflating: DataBase_100K/Level1/cluster7.bin
#   inflating: DataBase_100K/Level1/cluster8.bin
#   inflating: DataBase_100K/Level1/cluster9.bin
#   inflating: DataBase_100K/Level1/cluster10.bin
#   inflating: DataBase_100K/Level1/cluster11.bin
#   inflating: DataBase_100K/Level1/cluster12.bin
#   inflating: DataBase_100K/Level1/cluster13.bin
#   inflating: DataBase_100K/Level1/cluster14.bin
#   inflating: DataBase_100K/Level1/cluster15.bin
#   inflating: DataBase_100K/Level1/cluster16.bin
#   inflating: DataBase_100K/Level1/cluster17.bin
#   inflating: DataBase_100K/Level1/cluster18.bin
#   inflating: DataBase_100K/Level1/cluster19.bin
#   inflating: DataBase_100K/Level1/cluster20.bin
#   inflating: DataBase_100K/Level1/cluster21.bin
#   inflating: DataBase_100K/Level1/cluster22.bin
#   inflating: DataBase_100K/Level1/cluster23.bin
#   inflating: DataBase_100K/Level1/cluster24.bin
#   inflating: DataBase_100K/Level1/cluster25.bin
#   inflating: DataBase_100K/Level1/cluster26.bin
#   inflating: DataBase_100K/Level1/cluster27.bin
#   inflating: DataBase_100K/Level1/cluster28.bin
#   inflating: DataBase_100K/Level1/cluster29.bin
#   inflating: DataBase_100K/Level1/cluster30.bin
#   inflating: DataBase_100K/Level1/cluster31.bin
#   inflating: DataBase_100K/Level1/cluster32.bin
#   inflating: DataBase_100K/Level1/cluster33.bin
#   inflating: DataBase_100K/Level1/cluster34.bin
#   inflating: DataBase_100K/Level1/cluster35.bin
#   inflating: DataBase_100K/Level1/cluster36.bin
#   inflating: DataBase_100K/Level1/cluster37.bin
#   inflating: DataBase_100K/Level1/cluster38.bin
#   inflating: DataBase_100K/Level1/cluster39.bin
#   inflating: DataBase_100K/Level1/cluster40.bin
#   inflating: DataBase_100K/Level1/cluster41.bin
#   inflating: DataBase_100K/Level1/cluster42.bin
#   inflating: DataBase_100K/Level1/cluster43.bin
#   inflating: DataBase_100K/Level1/cluster44.bin
#   inflating: DataBase_100K/Level1/cluster45.bin
#   inflating: DataBase_100K/Level1/cluster46.bin
#   inflating: DataBase_100K/Level1/cluster47.bin
#   inflating: DataBase_100K/Level1/cluster48.bin
#   inflating: DataBase_100K/Level1/cluster49.bin
#   inflating: DataBase_100K/data.bin
# Archive:  saved_db_1m.zip
#    creating: DataBase_1M/
#    creating: DataBase_1M/Level1/
#   inflating: DataBase_1M/Level1/centroids.bin
#   inflating: DataBase_1M/Level1/cluster0.bin
#   inflating: DataBase_1M/Level1/cluster1.bin
#   inflating: DataBase_1M/Level1/cluster2.bin
#   inflating: DataBase_1M/Level1/cluster3.bin
#   inflating: DataBase_1M/Level1/cluster4.bin
#   inflating: DataBase_1M/Level1/cluster5.bin
#   inflating: DataBase_1M/Level1/cluster6.bin
#   inflating: DataBase_1M/Level1/cluster7.bin
#   inflating: DataBase_1M/Level1/cluster8.bin
#   inflating: DataBase_1M/Level1/cluster9.bin
#   inflating: DataBase_1M/Level1/cluster10.bin
#   inflating: DataBase_1M/Level1/cluster11.bin
#   inflating: DataBase_1M/Level1/cluster12.bin
#   inflating: DataBase_1M/Level1/cluster13.bin
#   inflating: DataBase_1M/Level1/cluster14.bin
#   inflating: DataBase_1M/Level1/cluster15.bin
#   inflating: DataBase_1M/Level1/cluster16.bin
#   inflating: DataBase_1M/Level1/cluster17.bin
#   inflating: DataBase_1M/Level1/cluster18.bin
#   inflating: DataBase_1M/Level1/cluster19.bin
#   inflating: DataBase_1M/Level1/cluster20.bin
#   inflating: DataBase_1M/Level1/cluster21.bin
#   inflating: DataBase_1M/Level1/cluster22.bin
#   inflating: DataBase_1M/Level1/cluster23.bin
#   inflating: DataBase_1M/Level1/cluster24.bin
#   inflating: DataBase_1M/Level1/cluster25.bin
#   inflating: DataBase_1M/Level1/cluster26.bin
#   inflating: DataBase_1M/Level1/cluster27.bin
#   inflating: DataBase_1M/Level1/cluster28.bin
#   inflating: DataBase_1M/Level1/cluster29.bin
#   inflating: DataBase_1M/Level1/cluster30.bin
#   inflating: DataBase_1M/Level1/cluster31.bin
#   inflating: DataBase_1M/Level1/cluster32.bin
#   inflating: DataBase_1M/Level1/cluster33.bin
#   inflating: DataBase_1M/Level1/cluster34.bin
#   inflating: DataBase_1M/Level1/cluster35.bin
#   inflating: DataBase_1M/Level1/cluster36.bin
#   inflating: DataBase_1M/Level1/cluster37.bin
#   inflating: DataBase_1M/Level1/cluster38.bin
#   inflating: DataBase_1M/Level1/cluster39.bin
#   inflating: DataBase_1M/Level1/cluster40.bin
#   inflating: DataBase_1M/Level1/cluster41.bin
#   inflating: DataBase_1M/Level1/cluster42.bin
#   inflating: DataBase_1M/Level1/cluster43.bin
#   inflating: DataBase_1M/Level1/cluster44.bin
#   inflating: DataBase_1M/Level1/cluster45.bin
#   inflating: DataBase_1M/Level1/cluster46.bin
#   inflating: DataBase_1M/Level1/cluster47.bin
#   inflating: DataBase_1M/Level1/cluster48.bin
#   inflating: DataBase_1M/Level1/cluster49.bin
#   inflating: DataBase_1M/Level1/cluster50.bin
#   inflating: DataBase_1M/Level1/cluster51.bin
#   inflating: DataBase_1M/Level1/cluster52.bin
#   inflating: DataBase_1M/Level1/cluster53.bin
#   inflating: DataBase_1M/Level1/cluster54.bin
#   inflating: DataBase_1M/Level1/cluster55.bin
#   inflating: DataBase_1M/Level1/cluster56.bin
#   inflating: DataBase_1M/Level1/cluster57.bin
#   inflating: DataBase_1M/Level1/cluster58.bin
#   inflating: DataBase_1M/Level1/cluster59.bin
#   inflating: DataBase_1M/Level1/cluster60.bin
#   inflating: DataBase_1M/Level1/cluster61.bin
#   inflating: DataBase_1M/Level1/cluster62.bin
#   inflating: DataBase_1M/Level1/cluster63.bin
#   inflating: DataBase_1M/Level1/cluster64.bin
#   inflating: DataBase_1M/Level1/cluster65.bin
#   inflating: DataBase_1M/Level1/cluster66.bin
#   inflating: DataBase_1M/Level1/cluster67.bin
#   inflating: DataBase_1M/Level1/cluster68.bin
#   inflating: DataBase_1M/Level1/cluster69.bin
#   inflating: DataBase_1M/Level1/cluster70.bin
#   inflating: DataBase_1M/Level1/cluster71.bin
#   inflating: DataBase_1M/Level1/cluster72.bin
#   inflating: DataBase_1M/Level1/cluster73.bin
#   inflating: DataBase_1M/Level1/cluster74.bin
#   inflating: DataBase_1M/Level1/cluster75.bin
#   inflating: DataBase_1M/Level1/cluster76.bin
#   inflating: DataBase_1M/Level1/cluster77.bin
#   inflating: DataBase_1M/Level1/cluster78.bin
#   inflating: DataBase_1M/Level1/cluster79.bin
#   inflating: DataBase_1M/Level1/cluster80.bin
#   inflating: DataBase_1M/Level1/cluster81.bin
#   inflating: DataBase_1M/Level1/cluster82.bin
#   inflating: DataBase_1M/Level1/cluster83.bin
#   inflating: DataBase_1M/Level1/cluster84.bin
#   inflating: DataBase_1M/Level1/cluster85.bin
#   inflating: DataBase_1M/Level1/cluster86.bin
#   inflating: DataBase_1M/Level1/cluster87.bin
#   inflating: DataBase_1M/Level1/cluster88.bin
#   inflating: DataBase_1M/Level1/cluster89.bin
#   inflating: DataBase_1M/Level1/cluster90.bin
#   inflating: DataBase_1M/Level1/cluster91.bin
#   inflating: DataBase_1M/Level1/cluster92.bin
#   inflating: DataBase_1M/Level1/cluster93.bin
#   inflating: DataBase_1M/Level1/cluster94.bin
#   inflating: DataBase_1M/Level1/cluster95.bin
#   inflating: DataBase_1M/Level1/cluster96.bin
#   inflating: DataBase_1M/Level1/cluster97.bin
#   inflating: DataBase_1M/Level1/cluster98.bin
#   inflating: DataBase_1M/Level1/cluster99.bin
#   inflating: DataBase_1M/Level1/cluster100.bin
#   inflating: DataBase_1M/Level1/cluster101.bin
#   inflating: DataBase_1M/Level1/cluster102.bin
#   inflating: DataBase_1M/Level1/cluster103.bin
#   inflating: DataBase_1M/Level1/cluster104.bin
#   inflating: DataBase_1M/Level1/cluster105.bin
#   inflating: DataBase_1M/Level1/cluster106.bin
#   inflating: DataBase_1M/Level1/cluster107.bin
#   inflating: DataBase_1M/Level1/cluster108.bin
#   inflating: DataBase_1M/Level1/cluster109.bin
#   inflating: DataBase_1M/Level1/cluster110.bin
#   inflating: DataBase_1M/Level1/cluster111.bin
#   inflating: DataBase_1M/Level1/cluster112.bin
#   inflating: DataBase_1M/Level1/cluster113.bin
#   inflating: DataBase_1M/Level1/cluster114.bin
#   inflating: DataBase_1M/Level1/cluster115.bin
#   inflating: DataBase_1M/Level1/cluster116.bin
#   inflating: DataBase_1M/Level1/cluster117.bin
#   inflating: DataBase_1M/Level1/cluster118.bin
#   inflating: DataBase_1M/Level1/cluster119.bin
#   inflating: DataBase_1M/Level1/cluster120.bin
#   inflating: DataBase_1M/Level1/cluster121.bin
#   inflating: DataBase_1M/Level1/cluster122.bin
#   inflating: DataBase_1M/Level1/cluster123.bin
#   inflating: DataBase_1M/Level1/cluster124.bin
#   inflating: DataBase_1M/Level1/cluster125.bin
#   inflating: DataBase_1M/Level1/cluster126.bin
#   inflating: DataBase_1M/Level1/cluster127.bin
#   inflating: DataBase_1M/Level1/cluster128.bin
#   inflating: DataBase_1M/Level1/cluster129.bin
#   inflating: DataBase_1M/Level1/cluster130.bin
#   inflating: DataBase_1M/Level1/cluster131.bin
#   inflating: DataBase_1M/Level1/cluster132.bin
#   inflating: DataBase_1M/Level1/cluster133.bin
#   inflating: DataBase_1M/Level1/cluster134.bin
#   inflating: DataBase_1M/Level1/cluster135.bin
#   inflating: DataBase_1M/Level1/cluster136.bin
#   inflating: DataBase_1M/Level1/cluster137.bin
#   inflating: DataBase_1M/Level1/cluster138.bin
#   inflating: DataBase_1M/Level1/cluster139.bin
#   inflating: DataBase_1M/Level1/cluster140.bin
#   inflating: DataBase_1M/Level1/cluster141.bin
#   inflating: DataBase_1M/Level1/cluster142.bin
#   inflating: DataBase_1M/Level1/cluster143.bin
#   inflating: DataBase_1M/Level1/cluster144.bin
#   inflating: DataBase_1M/Level1/cluster145.bin
#   inflating: DataBase_1M/Level1/cluster146.bin
#   inflating: DataBase_1M/Level1/cluster147.bin
#   inflating: DataBase_1M/Level1/cluster148.bin
#   inflating: DataBase_1M/Level1/cluster149.bin
#   inflating: DataBase_1M/Level1/cluster150.bin
#   inflating: DataBase_1M/Level1/cluster151.bin
#   inflating: DataBase_1M/Level1/cluster152.bin
#   inflating: DataBase_1M/Level1/cluster153.bin
#   inflating: DataBase_1M/Level1/cluster154.bin
#   inflating: DataBase_1M/Level1/cluster155.bin
#   inflating: DataBase_1M/Level1/cluster156.bin
#   inflating: DataBase_1M/Level1/cluster157.bin
#   inflating: DataBase_1M/Level1/cluster158.bin
#   inflating: DataBase_1M/Level1/cluster159.bin
#   inflating: DataBase_1M/Level1/cluster160.bin
#   inflating: DataBase_1M/Level1/cluster161.bin
#   inflating: DataBase_1M/Level1/cluster162.bin
#   inflating: DataBase_1M/Level1/cluster163.bin
#   inflating: DataBase_1M/Level1/cluster164.bin
#   inflating: DataBase_1M/Level1/cluster165.bin
#   inflating: DataBase_1M/Level1/cluster166.bin
#   inflating: DataBase_1M/Level1/cluster167.bin
#   inflating: DataBase_1M/Level1/cluster168.bin
#   inflating: DataBase_1M/Level1/cluster169.bin
#   inflating: DataBase_1M/Level1/cluster170.bin
#   inflating: DataBase_1M/Level1/cluster171.bin
#   inflating: DataBase_1M/Level1/cluster172.bin
#   inflating: DataBase_1M/Level1/cluster173.bin
#   inflating: DataBase_1M/Level1/cluster174.bin
#   inflating: DataBase_1M/Level1/cluster175.bin
#   inflating: DataBase_1M/Level1/cluster176.bin
#   inflating: DataBase_1M/Level1/cluster177.bin
#   inflating: DataBase_1M/Level1/cluster178.bin
#   inflating: DataBase_1M/Level1/cluster179.bin
#   inflating: DataBase_1M/Level1/cluster180.bin
#   inflating: DataBase_1M/Level1/cluster181.bin
#   inflating: DataBase_1M/Level1/cluster182.bin
#   inflating: DataBase_1M/Level1/cluster183.bin
#   inflating: DataBase_1M/Level1/cluster184.bin
#   inflating: DataBase_1M/Level1/cluster185.bin
#   inflating: DataBase_1M/Level1/cluster186.bin
#   inflating: DataBase_1M/Level1/cluster187.bin
#   inflating: DataBase_1M/Level1/cluster188.bin
#   inflating: DataBase_1M/Level1/cluster189.bin
#   inflating: DataBase_1M/Level1/cluster190.bin
#   inflating: DataBase_1M/Level1/cluster191.bin
#   inflating: DataBase_1M/Level1/cluster192.bin
#   inflating: DataBase_1M/Level1/cluster193.bin
#   inflating: DataBase_1M/Level1/cluster194.bin
#   inflating: DataBase_1M/Level1/cluster195.bin
#   inflating: DataBase_1M/Level1/cluster196.bin
#   inflating: DataBase_1M/Level1/cluster197.bin
#   inflating: DataBase_1M/Level1/cluster198.bin
#   inflating: DataBase_1M/Level1/cluster199.bin
#   inflating: DataBase_1M/data.bin
# Archive:  saved_db_5m.zip
#    creating: DataBase_5M/
#   inflating: DataBase_5M/data.bin
#    creating: DataBase_5M/Level1/
#   inflating: DataBase_5M/Level1/centroids.bin
#   inflating: DataBase_5M/Level1/cluster0.bin
#   inflating: DataBase_5M/Level1/cluster1.bin
#   inflating: DataBase_5M/Level1/cluster2.bin
#   inflating: DataBase_5M/Level1/cluster3.bin
#   inflating: DataBase_5M/Level1/cluster4.bin
#   inflating: DataBase_5M/Level1/cluster5.bin
#   inflating: DataBase_5M/Level1/cluster6.bin
#   inflating: DataBase_5M/Level1/cluster7.bin
#   inflating: DataBase_5M/Level1/cluster8.bin
#   inflating: DataBase_5M/Level1/cluster9.bin
#   inflating: DataBase_5M/Level1/cluster10.bin
#   inflating: DataBase_5M/Level1/cluster11.bin
#   inflating: DataBase_5M/Level1/cluster12.bin
#   inflating: DataBase_5M/Level1/cluster13.bin
#   inflating: DataBase_5M/Level1/cluster14.bin
#   inflating: DataBase_5M/Level1/cluster15.bin
#   inflating: DataBase_5M/Level1/cluster16.bin
#   inflating: DataBase_5M/Level1/cluster17.bin
#   inflating: DataBase_5M/Level1/cluster18.bin
#   inflating: DataBase_5M/Level1/cluster19.bin
#   inflating: DataBase_5M/Level1/cluster20.bin
#   inflating: DataBase_5M/Level1/cluster21.bin
#   inflating: DataBase_5M/Level1/cluster22.bin
#   inflating: DataBase_5M/Level1/cluster23.bin
#   inflating: DataBase_5M/Level1/cluster24.bin
#   inflating: DataBase_5M/Level1/cluster25.bin
#   inflating: DataBase_5M/Level1/cluster26.bin
#   inflating: DataBase_5M/Level1/cluster27.bin
#   inflating: DataBase_5M/Level1/cluster28.bin
#   inflating: DataBase_5M/Level1/cluster29.bin
#   inflating: DataBase_5M/Level1/cluster30.bin
#   inflating: DataBase_5M/Level1/cluster31.bin
#   inflating: DataBase_5M/Level1/cluster32.bin
#   inflating: DataBase_5M/Level1/cluster33.bin
#   inflating: DataBase_5M/Level1/cluster34.bin
#   inflating: DataBase_5M/Level1/cluster35.bin
#   inflating: DataBase_5M/Level1/cluster36.bin
#   inflating: DataBase_5M/Level1/cluster37.bin
#   inflating: DataBase_5M/Level1/cluster38.bin
#   inflating: DataBase_5M/Level1/cluster39.bin
#   inflating: DataBase_5M/Level1/cluster40.bin
#   inflating: DataBase_5M/Level1/cluster41.bin
#   inflating: DataBase_5M/Level1/cluster42.bin
#   inflating: DataBase_5M/Level1/cluster43.bin
#   inflating: DataBase_5M/Level1/cluster44.bin
#   inflating: DataBase_5M/Level1/cluster45.bin
#   inflating: DataBase_5M/Level1/cluster46.bin
#   inflating: DataBase_5M/Level1/cluster47.bin
#   inflating: DataBase_5M/Level1/cluster48.bin
#   inflating: DataBase_5M/Level1/cluster49.bin
#   inflating: DataBase_5M/Level1/cluster50.bin
#   inflating: DataBase_5M/Level1/cluster51.bin
#   inflating: DataBase_5M/Level1/cluster52.bin
#   inflating: DataBase_5M/Level1/cluster53.bin
#   inflating: DataBase_5M/Level1/cluster54.bin
#   inflating: DataBase_5M/Level1/cluster55.bin
#   inflating: DataBase_5M/Level1/cluster56.bin
#   inflating: DataBase_5M/Level1/cluster57.bin
#   inflating: DataBase_5M/Level1/cluster58.bin
#   inflating: DataBase_5M/Level1/cluster59.bin
#   inflating: DataBase_5M/Level1/cluster60.bin
#   inflating: DataBase_5M/Level1/cluster61.bin
#   inflating: DataBase_5M/Level1/cluster62.bin
#   inflating: DataBase_5M/Level1/cluster63.bin
#   inflating: DataBase_5M/Level1/cluster64.bin
#   inflating: DataBase_5M/Level1/cluster65.bin
#   inflating: DataBase_5M/Level1/cluster66.bin
#   inflating: DataBase_5M/Level1/cluster67.bin
#   inflating: DataBase_5M/Level1/cluster68.bin
#   inflating: DataBase_5M/Level1/cluster69.bin
#   inflating: DataBase_5M/Level1/cluster70.bin
#   inflating: DataBase_5M/Level1/cluster71.bin
#   inflating: DataBase_5M/Level1/cluster72.bin
#   inflating: DataBase_5M/Level1/cluster73.bin
#   inflating: DataBase_5M/Level1/cluster74.bin
#   inflating: DataBase_5M/Level1/cluster75.bin
#   inflating: DataBase_5M/Level1/cluster76.bin
#   inflating: DataBase_5M/Level1/cluster77.bin
#   inflating: DataBase_5M/Level1/cluster78.bin
#   inflating: DataBase_5M/Level1/cluster79.bin
#   inflating: DataBase_5M/Level1/cluster80.bin
#   inflating: DataBase_5M/Level1/cluster81.bin
#   inflating: DataBase_5M/Level1/cluster82.bin
#   inflating: DataBase_5M/Level1/cluster83.bin
#   inflating: DataBase_5M/Level1/cluster84.bin
#   inflating: DataBase_5M/Level1/cluster85.bin
#   inflating: DataBase_5M/Level1/cluster86.bin
#   inflating: DataBase_5M/Level1/cluster87.bin
#   inflating: DataBase_5M/Level1/cluster88.bin
#   inflating: DataBase_5M/Level1/cluster89.bin
#   inflating: DataBase_5M/Level1/cluster90.bin
#   inflating: DataBase_5M/Level1/cluster91.bin
#   inflating: DataBase_5M/Level1/cluster92.bin
#   inflating: DataBase_5M/Level1/cluster93.bin
#   inflating: DataBase_5M/Level1/cluster94.bin
#   inflating: DataBase_5M/Level1/cluster95.bin
#   inflating: DataBase_5M/Level1/cluster96.bin
#   inflating: DataBase_5M/Level1/cluster97.bin
#   inflating: DataBase_5M/Level1/cluster98.bin
#   inflating: DataBase_5M/Level1/cluster99.bin
#   inflating: DataBase_5M/Level1/cluster100.bin
#   inflating: DataBase_5M/Level1/cluster101.bin
#   inflating: DataBase_5M/Level1/cluster102.bin
#   inflating: DataBase_5M/Level1/cluster103.bin
#   inflating: DataBase_5M/Level1/cluster104.bin
#   inflating: DataBase_5M/Level1/cluster105.bin
#   inflating: DataBase_5M/Level1/cluster106.bin
#   inflating: DataBase_5M/Level1/cluster107.bin
#   inflating: DataBase_5M/Level1/cluster108.bin
#   inflating: DataBase_5M/Level1/cluster109.bin
#   inflating: DataBase_5M/Level1/cluster110.bin
#   inflating: DataBase_5M/Level1/cluster111.bin
#   inflating: DataBase_5M/Level1/cluster112.bin
#   inflating: DataBase_5M/Level1/cluster113.bin
#   inflating: DataBase_5M/Level1/cluster114.bin
#   inflating: DataBase_5M/Level1/cluster115.bin
#   inflating: DataBase_5M/Level1/cluster116.bin
#   inflating: DataBase_5M/Level1/cluster117.bin
#   inflating: DataBase_5M/Level1/cluster118.bin
#   inflating: DataBase_5M/Level1/cluster119.bin
#   inflating: DataBase_5M/Level1/cluster120.bin
#   inflating: DataBase_5M/Level1/cluster121.bin
#   inflating: DataBase_5M/Level1/cluster122.bin
#   inflating: DataBase_5M/Level1/cluster123.bin
#   inflating: DataBase_5M/Level1/cluster124.bin
#   inflating: DataBase_5M/Level1/cluster125.bin
#   inflating: DataBase_5M/Level1/cluster126.bin
#   inflating: DataBase_5M/Level1/cluster127.bin
#   inflating: DataBase_5M/Level1/cluster128.bin
#   inflating: DataBase_5M/Level1/cluster129.bin
#   inflating: DataBase_5M/Level1/cluster130.bin
#   inflating: DataBase_5M/Level1/cluster131.bin
#   inflating: DataBase_5M/Level1/cluster132.bin
#   inflating: DataBase_5M/Level1/cluster133.bin
#   inflating: DataBase_5M/Level1/cluster134.bin
#   inflating: DataBase_5M/Level1/cluster135.bin
#   inflating: DataBase_5M/Level1/cluster136.bin
#   inflating: DataBase_5M/Level1/cluster137.bin
#   inflating: DataBase_5M/Level1/cluster138.bin
#   inflating: DataBase_5M/Level1/cluster139.bin
#   inflating: DataBase_5M/Level1/cluster140.bin
#   inflating: DataBase_5M/Level1/cluster141.bin
#   inflating: DataBase_5M/Level1/cluster142.bin
#   inflating: DataBase_5M/Level1/cluster143.bin
#   inflating: DataBase_5M/Level1/cluster144.bin
#   inflating: DataBase_5M/Level1/cluster145.bin
#   inflating: DataBase_5M/Level1/cluster146.bin
#   inflating: DataBase_5M/Level1/cluster147.bin
#   inflating: DataBase_5M/Level1/cluster148.bin
#   inflating: DataBase_5M/Level1/cluster149.bin
#   inflating: DataBase_5M/Level1/cluster150.bin
#   inflating: DataBase_5M/Level1/cluster151.bin
#   inflating: DataBase_5M/Level1/cluster152.bin
#   inflating: DataBase_5M/Level1/cluster153.bin
#   inflating: DataBase_5M/Level1/cluster154.bin
#   inflating: DataBase_5M/Level1/cluster155.bin
#   inflating: DataBase_5M/Level1/cluster156.bin
#   inflating: DataBase_5M/Level1/cluster157.bin
#   inflating: DataBase_5M/Level1/cluster158.bin
#   inflating: DataBase_5M/Level1/cluster159.bin
#   inflating: DataBase_5M/Level1/cluster160.bin
#   inflating: DataBase_5M/Level1/cluster161.bin
#   inflating: DataBase_5M/Level1/cluster162.bin
#   inflating: DataBase_5M/Level1/cluster163.bin
#   inflating: DataBase_5M/Level1/cluster164.bin
#   inflating: DataBase_5M/Level1/cluster165.bin
#   inflating: DataBase_5M/Level1/cluster166.bin
#   inflating: DataBase_5M/Level1/cluster167.bin
#   inflating: DataBase_5M/Level1/cluster168.bin
#   inflating: DataBase_5M/Level1/cluster169.bin
#   inflating: DataBase_5M/Level1/cluster170.bin
#   inflating: DataBase_5M/Level1/cluster171.bin
#   inflating: DataBase_5M/Level1/cluster172.bin
#   inflating: DataBase_5M/Level1/cluster173.bin
#   inflating: DataBase_5M/Level1/cluster174.bin
#   inflating: DataBase_5M/Level1/cluster175.bin
#   inflating: DataBase_5M/Level1/cluster176.bin
#   inflating: DataBase_5M/Level1/cluster177.bin
#   inflating: DataBase_5M/Level1/cluster178.bin
#   inflating: DataBase_5M/Level1/cluster179.bin
#   inflating: DataBase_5M/Level1/cluster180.bin
#   inflating: DataBase_5M/Level1/cluster181.bin
#   inflating: DataBase_5M/Level1/cluster182.bin
#   inflating: DataBase_5M/Level1/cluster183.bin
#   inflating: DataBase_5M/Level1/cluster184.bin
#   inflating: DataBase_5M/Level1/cluster185.bin
#   inflating: DataBase_5M/Level1/cluster186.bin
#   inflating: DataBase_5M/Level1/cluster187.bin
#   inflating: DataBase_5M/Level1/cluster188.bin
#   inflating: DataBase_5M/Level1/cluster189.bin
#   inflating: DataBase_5M/Level1/cluster190.bin
#   inflating: DataBase_5M/Level1/cluster191.bin
#   inflating: DataBase_5M/Level1/cluster192.bin
#   inflating: DataBase_5M/Level1/cluster193.bin
#   inflating: DataBase_5M/Level1/cluster194.bin
#   inflating: DataBase_5M/Level1/cluster195.bin
#   inflating: DataBase_5M/Level1/cluster196.bin
#   inflating: DataBase_5M/Level1/cluster197.bin
#   inflating: DataBase_5M/Level1/cluster198.bin
#   inflating: DataBase_5M/Level1/cluster199.bin
#   inflating: DataBase_5M/Level1/cluster200.bin
#   inflating: DataBase_5M/Level1/cluster201.bin
#   inflating: DataBase_5M/Level1/cluster202.bin
#   inflating: DataBase_5M/Level1/cluster203.bin
#   inflating: DataBase_5M/Level1/cluster204.bin
#   inflating: DataBase_5M/Level1/cluster205.bin
#   inflating: DataBase_5M/Level1/cluster206.bin
#   inflating: DataBase_5M/Level1/cluster207.bin
#   inflating: DataBase_5M/Level1/cluster208.bin
#   inflating: DataBase_5M/Level1/cluster209.bin
#   inflating: DataBase_5M/Level1/cluster210.bin
#   inflating: DataBase_5M/Level1/cluster211.bin
#   inflating: DataBase_5M/Level1/cluster212.bin
#   inflating: DataBase_5M/Level1/cluster213.bin
#   inflating: DataBase_5M/Level1/cluster214.bin
#   inflating: DataBase_5M/Level1/cluster215.bin
#   inflating: DataBase_5M/Level1/cluster216.bin
#   inflating: DataBase_5M/Level1/cluster217.bin
#   inflating: DataBase_5M/Level1/cluster218.bin
#   inflating: DataBase_5M/Level1/cluster219.bin
#   inflating: DataBase_5M/Level1/cluster220.bin
#   inflating: DataBase_5M/Level1/cluster221.bin
#   inflating: DataBase_5M/Level1/cluster222.bin
#   inflating: DataBase_5M/Level1/cluster223.bin
#   inflating: DataBase_5M/Level1/cluster224.bin
#   inflating: DataBase_5M/Level1/cluster225.bin
#   inflating: DataBase_5M/Level1/cluster226.bin
#   inflating: DataBase_5M/Level1/cluster227.bin
#   inflating: DataBase_5M/Level1/cluster228.bin
#   inflating: DataBase_5M/Level1/cluster229.bin
#   inflating: DataBase_5M/Level1/cluster230.bin
#   inflating: DataBase_5M/Level1/cluster231.bin
#   inflating: DataBase_5M/Level1/cluster232.bin
#   inflating: DataBase_5M/Level1/cluster233.bin
#   inflating: DataBase_5M/Level1/cluster234.bin
#   inflating: DataBase_5M/Level1/cluster235.bin
#   inflating: DataBase_5M/Level1/cluster236.bin
#   inflating: DataBase_5M/Level1/cluster237.bin
#   inflating: DataBase_5M/Level1/cluster238.bin
#   inflating: DataBase_5M/Level1/cluster239.bin
#   inflating: DataBase_5M/Level1/cluster240.bin
#   inflating: DataBase_5M/Level1/cluster241.bin
#   inflating: DataBase_5M/Level1/cluster242.bin
#   inflating: DataBase_5M/Level1/cluster243.bin
#   inflating: DataBase_5M/Level1/cluster244.bin
#   inflating: DataBase_5M/Level1/cluster245.bin
#   inflating: DataBase_5M/Level1/cluster246.bin
#   inflating: DataBase_5M/Level1/cluster247.bin
#   inflating: DataBase_5M/Level1/cluster248.bin
#   inflating: DataBase_5M/Level1/cluster249.bin
#   inflating: DataBase_5M/Level1/cluster250.bin
#   inflating: DataBase_5M/Level1/cluster251.bin
#   inflating: DataBase_5M/Level1/cluster252.bin
#   inflating: DataBase_5M/Level1/cluster253.bin
#   inflating: DataBase_5M/Level1/cluster254.bin
#   inflating: DataBase_5M/Level1/cluster255.bin
#   inflating: DataBase_5M/Level1/cluster256.bin
#   inflating: DataBase_5M/Level1/cluster257.bin
#   inflating: DataBase_5M/Level1/cluster258.bin
#   inflating: DataBase_5M/Level1/cluster259.bin
#   inflating: DataBase_5M/Level1/cluster260.bin
#   inflating: DataBase_5M/Level1/cluster261.bin
#   inflating: DataBase_5M/Level1/cluster262.bin
#   inflating: DataBase_5M/Level1/cluster263.bin
#   inflating: DataBase_5M/Level1/cluster264.bin
#   inflating: DataBase_5M/Level1/cluster265.bin
#   inflating: DataBase_5M/Level1/cluster266.bin
#   inflating: DataBase_5M/Level1/cluster267.bin
#   inflating: DataBase_5M/Level1/cluster268.bin
#   inflating: DataBase_5M/Level1/cluster269.bin
#   inflating: DataBase_5M/Level1/cluster270.bin
#   inflating: DataBase_5M/Level1/cluster271.bin
#   inflating: DataBase_5M/Level1/cluster272.bin
#   inflating: DataBase_5M/Level1/cluster273.bin
#   inflating: DataBase_5M/Level1/cluster274.bin
#   inflating: DataBase_5M/Level1/cluster275.bin
#   inflating: DataBase_5M/Level1/cluster276.bin
#   inflating: DataBase_5M/Level1/cluster277.bin
#   inflating: DataBase_5M/Level1/cluster278.bin
#   inflating: DataBase_5M/Level1/cluster279.bin
#   inflating: DataBase_5M/Level1/cluster280.bin
#   inflating: DataBase_5M/Level1/cluster281.bin
#   inflating: DataBase_5M/Level1/cluster282.bin
#   inflating: DataBase_5M/Level1/cluster283.bin
#   inflating: DataBase_5M/Level1/cluster284.bin
#   inflating: DataBase_5M/Level1/cluster285.bin
#   inflating: DataBase_5M/Level1/cluster286.bin
#   inflating: DataBase_5M/Level1/cluster287.bin
#   inflating: DataBase_5M/Level1/cluster288.bin
#   inflating: DataBase_5M/Level1/cluster289.bin
#   inflating: DataBase_5M/Level1/cluster290.bin
#   inflating: DataBase_5M/Level1/cluster291.bin
#   inflating: DataBase_5M/Level1/cluster292.bin
#   inflating: DataBase_5M/Level1/cluster293.bin
#   inflating: DataBase_5M/Level1/cluster294.bin
#   inflating: DataBase_5M/Level1/cluster295.bin
#   inflating: DataBase_5M/Level1/cluster296.bin
#   inflating: DataBase_5M/Level1/cluster297.bin
#   inflating: DataBase_5M/Level1/cluster298.bin
#   inflating: DataBase_5M/Level1/cluster299.bin
#   inflating: DataBase_5M/Level1/cluster300.bin
#   inflating: DataBase_5M/Level1/cluster301.bin
#   inflating: DataBase_5M/Level1/cluster302.bin
#   inflating: DataBase_5M/Level1/cluster303.bin
#   inflating: DataBase_5M/Level1/cluster304.bin
#   inflating: DataBase_5M/Level1/cluster305.bin
#   inflating: DataBase_5M/Level1/cluster306.bin
#   inflating: DataBase_5M/Level1/cluster307.bin
#   inflating: DataBase_5M/Level1/cluster308.bin
#   inflating: DataBase_5M/Level1/cluster309.bin
#   inflating: DataBase_5M/Level1/cluster310.bin
#   inflating: DataBase_5M/Level1/cluster311.bin
#   inflating: DataBase_5M/Level1/cluster312.bin
#   inflating: DataBase_5M/Level1/cluster313.bin
#   inflating: DataBase_5M/Level1/cluster314.bin
#   inflating: DataBase_5M/Level1/cluster315.bin
#   inflating: DataBase_5M/Level1/cluster316.bin
#   inflating: DataBase_5M/Level1/cluster317.bin
#   inflating: DataBase_5M/Level1/cluster318.bin
#   inflating: DataBase_5M/Level1/cluster319.bin
#   inflating: DataBase_5M/Level1/cluster320.bin
#   inflating: DataBase_5M/Level1/cluster321.bin
#   inflating: DataBase_5M/Level1/cluster322.bin
#   inflating: DataBase_5M/Level1/cluster323.bin
#   inflating: DataBase_5M/Level1/cluster324.bin
#   inflating: DataBase_5M/Level1/cluster325.bin
#   inflating: DataBase_5M/Level1/cluster326.bin
#   inflating: DataBase_5M/Level1/cluster327.bin
#   inflating: DataBase_5M/Level1/cluster328.bin
#   inflating: DataBase_5M/Level1/cluster329.bin
#   inflating: DataBase_5M/Level1/cluster330.bin
#   inflating: DataBase_5M/Level1/cluster331.bin
#   inflating: DataBase_5M/Level1/cluster332.bin
#   inflating: DataBase_5M/Level1/cluster333.bin
#   inflating: DataBase_5M/Level1/cluster334.bin
#   inflating: DataBase_5M/Level1/cluster335.bin
#   inflating: DataBase_5M/Level1/cluster336.bin
#   inflating: DataBase_5M/Level1/cluster337.bin
#   inflating: DataBase_5M/Level1/cluster338.bin
#   inflating: DataBase_5M/Level1/cluster339.bin
#   inflating: DataBase_5M/Level1/cluster340.bin
#   inflating: DataBase_5M/Level1/cluster341.bin
#   inflating: DataBase_5M/Level1/cluster342.bin
#   inflating: DataBase_5M/Level1/cluster343.bin
#   inflating: DataBase_5M/Level1/cluster344.bin
#   inflating: DataBase_5M/Level1/cluster345.bin
#   inflating: DataBase_5M/Level1/cluster346.bin
#   inflating: DataBase_5M/Level1/cluster347.bin
#   inflating: DataBase_5M/Level1/cluster348.bin
#   inflating: DataBase_5M/Level1/cluster349.bin
#   inflating: DataBase_5M/Level1/cluster350.bin
#   inflating: DataBase_5M/Level1/cluster351.bin
#   inflating: DataBase_5M/Level1/cluster352.bin
#   inflating: DataBase_5M/Level1/cluster353.bin
#   inflating: DataBase_5M/Level1/cluster354.bin
#   inflating: DataBase_5M/Level1/cluster355.bin
#   inflating: DataBase_5M/Level1/cluster356.bin
#   inflating: DataBase_5M/Level1/cluster357.bin
#   inflating: DataBase_5M/Level1/cluster358.bin
#   inflating: DataBase_5M/Level1/cluster359.bin
#   inflating: DataBase_5M/Level1/cluster360.bin
#   inflating: DataBase_5M/Level1/cluster361.bin
#   inflating: DataBase_5M/Level1/cluster362.bin
#   inflating: DataBase_5M/Level1/cluster363.bin
#   inflating: DataBase_5M/Level1/cluster364.bin
#   inflating: DataBase_5M/Level1/cluster365.bin
#   inflating: DataBase_5M/Level1/cluster366.bin
#   inflating: DataBase_5M/Level1/cluster367.bin
#   inflating: DataBase_5M/Level1/cluster368.bin
#   inflating: DataBase_5M/Level1/cluster369.bin
#   inflating: DataBase_5M/Level1/cluster370.bin
#   inflating: DataBase_5M/Level1/cluster371.bin
#   inflating: DataBase_5M/Level1/cluster372.bin
#   inflating: DataBase_5M/Level1/cluster373.bin
#   inflating: DataBase_5M/Level1/cluster374.bin
#   inflating: DataBase_5M/Level1/cluster375.bin
#   inflating: DataBase_5M/Level1/cluster376.bin
#   inflating: DataBase_5M/Level1/cluster377.bin
#   inflating: DataBase_5M/Level1/cluster378.bin
#   inflating: DataBase_5M/Level1/cluster379.bin
#   inflating: DataBase_5M/Level1/cluster380.bin
#   inflating: DataBase_5M/Level1/cluster381.bin
#   inflating: DataBase_5M/Level1/cluster382.bin
#   inflating: DataBase_5M/Level1/cluster383.bin
#   inflating: DataBase_5M/Level1/cluster384.bin
#   inflating: DataBase_5M/Level1/cluster385.bin
#   inflating: DataBase_5M/Level1/cluster386.bin
#   inflating: DataBase_5M/Level1/cluster387.bin
#   inflating: DataBase_5M/Level1/cluster388.bin
#   inflating: DataBase_5M/Level1/cluster389.bin
#   inflating: DataBase_5M/Level1/cluster390.bin
#   inflating: DataBase_5M/Level1/cluster391.bin
#   inflating: DataBase_5M/Level1/cluster392.bin
#   inflating: DataBase_5M/Level1/cluster393.bin
#   inflating: DataBase_5M/Level1/cluster394.bin
#   inflating: DataBase_5M/Level1/cluster395.bin
#   inflating: DataBase_5M/Level1/cluster396.bin
#   inflating: DataBase_5M/Level1/cluster397.bin
#   inflating: DataBase_5M/Level1/cluster398.bin
#   inflating: DataBase_5M/Level1/cluster399.bin
#   inflating: DataBase_5M/Level1/cluster400.bin
#   inflating: DataBase_5M/Level1/cluster401.bin
#   inflating: DataBase_5M/Level1/cluster402.bin
#   inflating: DataBase_5M/Level1/cluster403.bin
#   inflating: DataBase_5M/Level1/cluster404.bin
#   inflating: DataBase_5M/Level1/cluster405.bin
#   inflating: DataBase_5M/Level1/cluster406.bin
#   inflating: DataBase_5M/Level1/cluster407.bin
#   inflating: DataBase_5M/Level1/cluster408.bin
#   inflating: DataBase_5M/Level1/cluster409.bin
#   inflating: DataBase_5M/Level1/cluster410.bin
#   inflating: DataBase_5M/Level1/cluster411.bin
#   inflating: DataBase_5M/Level1/cluster412.bin
#   inflating: DataBase_5M/Level1/cluster413.bin
#   inflating: DataBase_5M/Level1/cluster414.bin
#   inflating: DataBase_5M/Level1/cluster415.bin
#   inflating: DataBase_5M/Level1/cluster416.bin
#   inflating: DataBase_5M/Level1/cluster417.bin
#   inflating: DataBase_5M/Level1/cluster418.bin
#   inflating: DataBase_5M/Level1/cluster419.bin
#   inflating: DataBase_5M/Level1/cluster420.bin
#   inflating: DataBase_5M/Level1/cluster421.bin
#   inflating: DataBase_5M/Level1/cluster422.bin
#   inflating: DataBase_5M/Level1/cluster423.bin
#   inflating: DataBase_5M/Level1/cluster424.bin
#   inflating: DataBase_5M/Level1/cluster425.bin
#   inflating: DataBase_5M/Level1/cluster426.bin
#   inflating: DataBase_5M/Level1/cluster427.bin
#   inflating: DataBase_5M/Level1/cluster428.bin
#   inflating: DataBase_5M/Level1/cluster429.bin
#   inflating: DataBase_5M/Level1/cluster430.bin
#   inflating: DataBase_5M/Level1/cluster431.bin
#   inflating: DataBase_5M/Level1/cluster432.bin
#   inflating: DataBase_5M/Level1/cluster433.bin
#   inflating: DataBase_5M/Level1/cluster434.bin
#   inflating: DataBase_5M/Level1/cluster435.bin
#   inflating: DataBase_5M/Level1/cluster436.bin
#   inflating: DataBase_5M/Level1/cluster437.bin
#   inflating: DataBase_5M/Level1/cluster438.bin
#   inflating: DataBase_5M/Level1/cluster439.bin
#   inflating: DataBase_5M/Level1/cluster440.bin
#   inflating: DataBase_5M/Level1/cluster441.bin
#   inflating: DataBase_5M/Level1/cluster442.bin
#   inflating: DataBase_5M/Level1/cluster443.bin
#   inflating: DataBase_5M/Level1/cluster444.bin
#   inflating: DataBase_5M/Level1/cluster445.bin
#   inflating: DataBase_5M/Level1/cluster446.bin
#   inflating: DataBase_5M/Level1/cluster447.bin
#   inflating: DataBase_5M/Level1/cluster448.bin
#   inflating: DataBase_5M/Level1/cluster449.bin
#   inflating: DataBase_5M/Level1/cluster450.bin
#   inflating: DataBase_5M/Level1/cluster451.bin
#   inflating: DataBase_5M/Level1/cluster452.bin
#   inflating: DataBase_5M/Level1/cluster453.bin
#   inflating: DataBase_5M/Level1/cluster454.bin
#   inflating: DataBase_5M/Level1/cluster455.bin
#   inflating: DataBase_5M/Level1/cluster456.bin
#   inflating: DataBase_5M/Level1/cluster457.bin
#   inflating: DataBase_5M/Level1/cluster458.bin
#   inflating: DataBase_5M/Level1/cluster459.bin
#   inflating: DataBase_5M/Level1/cluster460.bin
#   inflating: DataBase_5M/Level1/cluster461.bin
#   inflating: DataBase_5M/Level1/cluster462.bin
#   inflating: DataBase_5M/Level1/cluster463.bin
#   inflating: DataBase_5M/Level1/cluster464.bin
#   inflating: DataBase_5M/Level1/cluster465.bin
#   inflating: DataBase_5M/Level1/cluster466.bin
#   inflating: DataBase_5M/Level1/cluster467.bin
#   inflating: DataBase_5M/Level1/cluster468.bin
#   inflating: DataBase_5M/Level1/cluster469.bin
#   inflating: DataBase_5M/Level1/cluster470.bin
#   inflating: DataBase_5M/Level1/cluster471.bin
#   inflating: DataBase_5M/Level1/cluster472.bin
#   inflating: DataBase_5M/Level1/cluster473.bin
#   inflating: DataBase_5M/Level1/cluster474.bin
#   inflating: DataBase_5M/Level1/cluster475.bin
#   inflating: DataBase_5M/Level1/cluster476.bin
#   inflating: DataBase_5M/Level1/cluster477.bin
#   inflating: DataBase_5M/Level1/cluster478.bin
#   inflating: DataBase_5M/Level1/cluster479.bin
#   inflating: DataBase_5M/Level1/cluster480.bin
#   inflating: DataBase_5M/Level1/cluster481.bin
#   inflating: DataBase_5M/Level1/cluster482.bin
#   inflating: DataBase_5M/Level1/cluster483.bin
#   inflating: DataBase_5M/Level1/cluster484.bin
#   inflating: DataBase_5M/Level1/cluster485.bin
#   inflating: DataBase_5M/Level1/cluster486.bin
#   inflating: DataBase_5M/Level1/cluster487.bin
#   inflating: DataBase_5M/Level1/cluster488.bin
#   inflating: DataBase_5M/Level1/cluster489.bin
#   inflating: DataBase_5M/Level1/cluster490.bin
#   inflating: DataBase_5M/Level1/cluster491.bin
#   inflating: DataBase_5M/Level1/cluster492.bin
#   inflating: DataBase_5M/Level1/cluster493.bin
#   inflating: DataBase_5M/Level1/cluster494.bin
#   inflating: DataBase_5M/Level1/cluster495.bin
#   inflating: DataBase_5M/Level1/cluster496.bin
#   inflating: DataBase_5M/Level1/cluster497.bin
#   inflating: DataBase_5M/Level1/cluster498.bin
#   inflating: DataBase_5M/Level1/cluster499.bin
# Archive:  saved_db_10m.zip
#    creating: DataBase_10M/
#    creating: DataBase_10M/Level1/
#   inflating: DataBase_10M/Level1/centroids.bin
#   inflating: DataBase_10M/Level1/cluster0.bin
#   inflating: DataBase_10M/Level1/cluster1.bin
#   inflating: DataBase_10M/Level1/cluster2.bin
#   inflating: DataBase_10M/Level1/cluster3.bin
#   inflating: DataBase_10M/Level1/cluster4.bin
#   inflating: DataBase_10M/Level1/cluster5.bin
#   inflating: DataBase_10M/Level1/cluster6.bin
#   inflating: DataBase_10M/Level1/cluster7.bin
#   inflating: DataBase_10M/Level1/cluster8.bin
#   inflating: DataBase_10M/Level1/cluster9.bin
#   inflating: DataBase_10M/Level1/cluster10.bin
#   inflating: DataBase_10M/Level1/cluster11.bin
#   inflating: DataBase_10M/Level1/cluster12.bin
#   inflating: DataBase_10M/Level1/cluster13.bin
#   inflating: DataBase_10M/Level1/cluster14.bin
#   inflating: DataBase_10M/Level1/cluster15.bin
#   inflating: DataBase_10M/Level1/cluster16.bin
#   inflating: DataBase_10M/Level1/cluster17.bin
#   inflating: DataBase_10M/Level1/cluster18.bin
#   inflating: DataBase_10M/Level1/cluster19.bin
#   inflating: DataBase_10M/Level1/cluster20.bin
#   inflating: DataBase_10M/Level1/cluster21.bin
#   inflating: DataBase_10M/Level1/cluster22.bin
#   inflating: DataBase_10M/Level1/cluster23.bin
#   inflating: DataBase_10M/Level1/cluster24.bin
#   inflating: DataBase_10M/Level1/cluster25.bin
#   inflating: DataBase_10M/Level1/cluster26.bin
#   inflating: DataBase_10M/Level1/cluster27.bin
#   inflating: DataBase_10M/Level1/cluster28.bin
#   inflating: DataBase_10M/Level1/cluster29.bin
#   inflating: DataBase_10M/Level1/cluster30.bin
#   inflating: DataBase_10M/Level1/cluster31.bin
#   inflating: DataBase_10M/Level1/cluster32.bin
#   inflating: DataBase_10M/Level1/cluster33.bin
#   inflating: DataBase_10M/Level1/cluster34.bin
#   inflating: DataBase_10M/Level1/cluster35.bin
#   inflating: DataBase_10M/Level1/cluster36.bin
#   inflating: DataBase_10M/Level1/cluster37.bin
#   inflating: DataBase_10M/Level1/cluster38.bin
#   inflating: DataBase_10M/Level1/cluster39.bin
#   inflating: DataBase_10M/Level1/cluster40.bin
#   inflating: DataBase_10M/Level1/cluster41.bin
#   inflating: DataBase_10M/Level1/cluster42.bin
#   inflating: DataBase_10M/Level1/cluster43.bin
#   inflating: DataBase_10M/Level1/cluster44.bin
#   inflating: DataBase_10M/Level1/cluster45.bin
#   inflating: DataBase_10M/Level1/cluster46.bin
#   inflating: DataBase_10M/Level1/cluster47.bin
#   inflating: DataBase_10M/Level1/cluster48.bin
#   inflating: DataBase_10M/Level1/cluster49.bin
#   inflating: DataBase_10M/Level1/cluster50.bin
#   inflating: DataBase_10M/Level1/cluster51.bin
#   inflating: DataBase_10M/Level1/cluster52.bin
#   inflating: DataBase_10M/Level1/cluster53.bin
#   inflating: DataBase_10M/Level1/cluster54.bin
#   inflating: DataBase_10M/Level1/cluster55.bin
#   inflating: DataBase_10M/Level1/cluster56.bin
#   inflating: DataBase_10M/Level1/cluster57.bin
#   inflating: DataBase_10M/Level1/cluster58.bin
#   inflating: DataBase_10M/Level1/cluster59.bin
#   inflating: DataBase_10M/Level1/cluster60.bin
#   inflating: DataBase_10M/Level1/cluster61.bin
#   inflating: DataBase_10M/Level1/cluster62.bin
#   inflating: DataBase_10M/Level1/cluster63.bin
#   inflating: DataBase_10M/Level1/cluster64.bin
#   inflating: DataBase_10M/Level1/cluster65.bin
#   inflating: DataBase_10M/Level1/cluster66.bin
#   inflating: DataBase_10M/Level1/cluster67.bin
#   inflating: DataBase_10M/Level1/cluster68.bin
#   inflating: DataBase_10M/Level1/cluster69.bin
#   inflating: DataBase_10M/Level1/cluster70.bin
#   inflating: DataBase_10M/Level1/cluster71.bin
#   inflating: DataBase_10M/Level1/cluster72.bin
#   inflating: DataBase_10M/Level1/cluster73.bin
#   inflating: DataBase_10M/Level1/cluster74.bin
#   inflating: DataBase_10M/Level1/cluster75.bin
#   inflating: DataBase_10M/Level1/cluster76.bin
#   inflating: DataBase_10M/Level1/cluster77.bin
#   inflating: DataBase_10M/Level1/cluster78.bin
#   inflating: DataBase_10M/Level1/cluster79.bin
#   inflating: DataBase_10M/Level1/cluster80.bin
#   inflating: DataBase_10M/Level1/cluster81.bin
#   inflating: DataBase_10M/Level1/cluster82.bin
#   inflating: DataBase_10M/Level1/cluster83.bin
#   inflating: DataBase_10M/Level1/cluster84.bin
#   inflating: DataBase_10M/Level1/cluster85.bin
#   inflating: DataBase_10M/Level1/cluster86.bin
#   inflating: DataBase_10M/Level1/cluster87.bin
#   inflating: DataBase_10M/Level1/cluster88.bin
#   inflating: DataBase_10M/Level1/cluster89.bin
#   inflating: DataBase_10M/Level1/cluster90.bin
#   inflating: DataBase_10M/Level1/cluster91.bin
#   inflating: DataBase_10M/Level1/cluster92.bin
#   inflating: DataBase_10M/Level1/cluster93.bin
#   inflating: DataBase_10M/Level1/cluster94.bin
#   inflating: DataBase_10M/Level1/cluster95.bin
#   inflating: DataBase_10M/Level1/cluster96.bin
#   inflating: DataBase_10M/Level1/cluster97.bin
#   inflating: DataBase_10M/Level1/cluster98.bin
#   inflating: DataBase_10M/Level1/cluster99.bin
#   inflating: DataBase_10M/Level1/cluster100.bin
#   inflating: DataBase_10M/Level1/cluster101.bin
#   inflating: DataBase_10M/Level1/cluster102.bin
#   inflating: DataBase_10M/Level1/cluster103.bin
#   inflating: DataBase_10M/Level1/cluster104.bin
#   inflating: DataBase_10M/Level1/cluster105.bin
#   inflating: DataBase_10M/Level1/cluster106.bin
#   inflating: DataBase_10M/Level1/cluster107.bin
#   inflating: DataBase_10M/Level1/cluster108.bin
#   inflating: DataBase_10M/Level1/cluster109.bin
#   inflating: DataBase_10M/Level1/cluster110.bin
#   inflating: DataBase_10M/Level1/cluster111.bin
#   inflating: DataBase_10M/Level1/cluster112.bin
#   inflating: DataBase_10M/Level1/cluster113.bin
#   inflating: DataBase_10M/Level1/cluster114.bin
#   inflating: DataBase_10M/Level1/cluster115.bin
#   inflating: DataBase_10M/Level1/cluster116.bin
#   inflating: DataBase_10M/Level1/cluster117.bin
#   inflating: DataBase_10M/Level1/cluster118.bin
#   inflating: DataBase_10M/Level1/cluster119.bin
#   inflating: DataBase_10M/Level1/cluster120.bin
#   inflating: DataBase_10M/Level1/cluster121.bin
#   inflating: DataBase_10M/Level1/cluster122.bin
#   inflating: DataBase_10M/Level1/cluster123.bin
#   inflating: DataBase_10M/Level1/cluster124.bin
#   inflating: DataBase_10M/Level1/cluster125.bin
#   inflating: DataBase_10M/Level1/cluster126.bin
#   inflating: DataBase_10M/Level1/cluster127.bin
#   inflating: DataBase_10M/Level1/cluster128.bin
#   inflating: DataBase_10M/Level1/cluster129.bin
#   inflating: DataBase_10M/Level1/cluster130.bin
#   inflating: DataBase_10M/Level1/cluster131.bin
#   inflating: DataBase_10M/Level1/cluster132.bin
#   inflating: DataBase_10M/Level1/cluster133.bin
#   inflating: DataBase_10M/Level1/cluster134.bin
#   inflating: DataBase_10M/Level1/cluster135.bin
#   inflating: DataBase_10M/Level1/cluster136.bin
#   inflating: DataBase_10M/Level1/cluster137.bin
#   inflating: DataBase_10M/Level1/cluster138.bin
#   inflating: DataBase_10M/Level1/cluster139.bin
#   inflating: DataBase_10M/Level1/cluster140.bin
#   inflating: DataBase_10M/Level1/cluster141.bin
#   inflating: DataBase_10M/Level1/cluster142.bin
#   inflating: DataBase_10M/Level1/cluster143.bin
#   inflating: DataBase_10M/Level1/cluster144.bin
#   inflating: DataBase_10M/Level1/cluster145.bin
#   inflating: DataBase_10M/Level1/cluster146.bin
#   inflating: DataBase_10M/Level1/cluster147.bin
#   inflating: DataBase_10M/Level1/cluster148.bin
#   inflating: DataBase_10M/Level1/cluster149.bin
#   inflating: DataBase_10M/Level1/cluster150.bin
#   inflating: DataBase_10M/Level1/cluster151.bin
#   inflating: DataBase_10M/Level1/cluster152.bin
#   inflating: DataBase_10M/Level1/cluster153.bin
#   inflating: DataBase_10M/Level1/cluster154.bin
#   inflating: DataBase_10M/Level1/cluster155.bin
#   inflating: DataBase_10M/Level1/cluster156.bin
#   inflating: DataBase_10M/Level1/cluster157.bin
#   inflating: DataBase_10M/Level1/cluster158.bin
#   inflating: DataBase_10M/Level1/cluster159.bin
#   inflating: DataBase_10M/Level1/cluster160.bin
#   inflating: DataBase_10M/Level1/cluster161.bin
#   inflating: DataBase_10M/Level1/cluster162.bin
#   inflating: DataBase_10M/Level1/cluster163.bin
#   inflating: DataBase_10M/Level1/cluster164.bin
#   inflating: DataBase_10M/Level1/cluster165.bin
#   inflating: DataBase_10M/Level1/cluster166.bin
#   inflating: DataBase_10M/Level1/cluster167.bin
#   inflating: DataBase_10M/Level1/cluster168.bin
#   inflating: DataBase_10M/Level1/cluster169.bin
#   inflating: DataBase_10M/Level1/cluster170.bin
#   inflating: DataBase_10M/Level1/cluster171.bin
#   inflating: DataBase_10M/Level1/cluster172.bin
#   inflating: DataBase_10M/Level1/cluster173.bin
#   inflating: DataBase_10M/Level1/cluster174.bin
#   inflating: DataBase_10M/Level1/cluster175.bin
#   inflating: DataBase_10M/Level1/cluster176.bin
#   inflating: DataBase_10M/Level1/cluster177.bin
#   inflating: DataBase_10M/Level1/cluster178.bin
#   inflating: DataBase_10M/Level1/cluster179.bin
#   inflating: DataBase_10M/Level1/cluster180.bin
#   inflating: DataBase_10M/Level1/cluster181.bin
#   inflating: DataBase_10M/Level1/cluster182.bin
#   inflating: DataBase_10M/Level1/cluster183.bin
#   inflating: DataBase_10M/Level1/cluster184.bin
#   inflating: DataBase_10M/Level1/cluster185.bin
#   inflating: DataBase_10M/Level1/cluster186.bin
#   inflating: DataBase_10M/Level1/cluster187.bin
#   inflating: DataBase_10M/Level1/cluster188.bin
#   inflating: DataBase_10M/Level1/cluster189.bin
#   inflating: DataBase_10M/Level1/cluster190.bin
#   inflating: DataBase_10M/Level1/cluster191.bin
#   inflating: DataBase_10M/Level1/cluster192.bin
#   inflating: DataBase_10M/Level1/cluster193.bin
# ...
#   inflating: DataBase_10M/Level1/cluster684.bin
#   inflating: DataBase_10M/Level1/cluster685.bin
#   inflating: DataBase_10M/Level1/cluster686.bin
#   inflating: DataBase_10M/Level1/cluster687.bin
#   inflating: DataBase_10M/Level1/cluster688.bin
#   inflating: DataBase_10M/Level1/cluster689.bin
#   inflating: DataBase_10M/Level1/cluster690.bin
#   inflating: DataBase_10M/Level1/cluster691.bin
#   inflating: DataBase_10M/Level1/cluster692.bin
#   inflating: DataBase_10M/Level1/cluster693.bin
#   inflating: DataBase_10M/Level1/cluster694.bin
#   inflating: DataBase_10M/Level1/cluster695.bin
#   inflating: DataBase_10M/Level1/cluster696.bin
#   inflating: DataBase_10M/Level1/cluster697.bin
#   inflating: DataBase_10M/Level1/cluster698.bin
#   inflating: DataBase_10M/Level1/cluster699.bin
#   inflating: DataBase_10M/Level1/cluster700.bin
#   inflating: DataBase_10M/Level1/cluster701.bin
#   inflating: DataBase_10M/Level1/cluster702.bin
#   inflating: DataBase_10M/Level1/cluster703.bin
#   inflating: DataBase_10M/Level1/cluster704.bin
#   inflating: DataBase_10M/Level1/cluster705.bin
#   inflating: DataBase_10M/Level1/cluster706.bin
#   inflating: DataBase_10M/Level1/cluster707.bin
#   inflating: DataBase_10M/Level1/cluster708.bin
#   inflating: DataBase_10M/Level1/cluster709.bin
#   inflating: DataBase_10M/Level1/cluster710.bin
#   inflating: DataBase_10M/Level1/cluster711.bin
#   inflating: DataBase_10M/Level1/cluster712.bin
#   inflating: DataBase_10M/Level1/cluster713.bin
#   inflating: DataBase_10M/Level1/cluster714.bin
#   inflating: DataBase_10M/Level1/cluster715.bin
#   inflating: DataBase_10M/Level1/cluster716.bin
#   inflating: DataBase_10M/Level1/cluster717.bin
#   inflating: DataBase_10M/Level1/cluster718.bin
#   inflating: DataBase_10M/Level1/cluster719.bin
#   inflating: DataBase_10M/Level1/cluster720.bin
#   inflating: DataBase_10M/Level1/cluster721.bin
#   inflating: DataBase_10M/Level1/cluster722.bin
#   inflating: DataBase_10M/Level1/cluster723.bin
#   inflating: DataBase_10M/Level1/cluster724.bin
#   inflating: DataBase_10M/Level1/cluster725.bin
#   inflating: DataBase_10M/Level1/cluster726.bin
#   inflating: DataBase_10M/Level1/cluster727.bin
#   inflating: DataBase_10M/Level1/cluster728.bin
#   inflating: DataBase_10M/Level1/cluster729.bin
#   inflating: DataBase_10M/Level1/cluster730.bin
#   inflating: DataBase_10M/Level1/cluster731.bin
#   inflating: DataBase_10M/Level1/cluster732.bin
#   inflating: DataBase_10M/Level1/cluster733.bin
#   inflating: DataBase_10M/Level1/cluster734.bin
#   inflating: DataBase_10M/Level1/cluster735.bin
#   inflating: DataBase_10M/Level1/cluster736.bin
#   inflating: DataBase_10M/Level1/cluster737.bin
#   inflating: DataBase_10M/Level1/cluster738.bin
#   inflating: DataBase_10M/Level1/cluster739.bin
#   inflating: DataBase_10M/Level1/cluster740.bin
#   inflating: DataBase_10M/Level1/cluster741.bin
#   inflating: DataBase_10M/Level1/cluster742.bin
#   inflating: DataBase_10M/Level1/cluster743.bin
#   inflating: DataBase_10M/Level1/cluster744.bin
#   inflating: DataBase_10M/Level1/cluster745.bin
#   inflating: DataBase_10M/Level1/cluster746.bin
#   inflating: DataBase_10M/Level1/cluster747.bin
#   inflating: DataBase_10M/Level1/cluster748.bin
#   inflating: DataBase_10M/Level1/cluster749.bin
#   inflating: DataBase_10M/Level1/cluster750.bin
#   inflating: DataBase_10M/Level1/cluster751.bin
#   inflating: DataBase_10M/Level1/cluster752.bin
#   inflating: DataBase_10M/Level1/cluster753.bin
#   inflating: DataBase_10M/Level1/cluster754.bin
#   inflating: DataBase_10M/Level1/cluster755.bin
#   inflating: DataBase_10M/Level1/cluster756.bin
#   inflating: DataBase_10M/Level1/cluster757.bin
#   inflating: DataBase_10M/Level1/cluster758.bin
#   inflating: DataBase_10M/Level1/cluster759.bin
#   inflating: DataBase_10M/Level1/cluster760.bin
#   inflating: DataBase_10M/Level1/cluster761.bin
#   inflating: DataBase_10M/Level1/cluster762.bin
#   inflating: DataBase_10M/Level1/cluster763.bin
#   inflating: DataBase_10M/Level1/cluster764.bin
#   inflating: DataBase_10M/Level1/cluster765.bin
#   inflating: DataBase_10M/Level1/cluster766.bin
#   inflating: DataBase_10M/Level1/cluster767.bin
#   inflating: DataBase_10M/Level1/cluster768.bin
#   inflating: DataBase_10M/Level1/cluster769.bin
#   inflating: DataBase_10M/Level1/cluster770.bin
#   inflating: DataBase_10M/Level1/cluster771.bin
#   inflating: DataBase_10M/Level1/cluster772.bin
#   inflating: DataBase_10M/Level1/cluster773.bin
#   inflating: DataBase_10M/Level1/cluster774.bin
#   inflating: DataBase_10M/Level1/cluster775.bin
#   inflating: DataBase_10M/Level1/cluster776.bin
#   inflating: DataBase_10M/Level1/cluster777.bin
#   inflating: DataBase_10M/Level1/cluster778.bin
#   inflating: DataBase_10M/Level1/cluster779.bin
#   inflating: DataBase_10M/Level1/cluster780.bin
#   inflating: DataBase_10M/Level1/cluster781.bin
#   inflating: DataBase_10M/Level1/cluster782.bin
#   inflating: DataBase_10M/Level1/cluster783.bin
#   inflating: DataBase_10M/Level1/cluster784.bin
#   inflating: DataBase_10M/Level1/cluster785.bin
#   inflating: DataBase_10M/Level1/cluster786.bin
#   inflating: DataBase_10M/Level1/cluster787.bin
#   inflating: DataBase_10M/Level1/cluster788.bin
#   inflating: DataBase_10M/Level1/cluster789.bin
#   inflating: DataBase_10M/Level1/cluster790.bin
#   inflating: DataBase_10M/Level1/cluster791.bin
#   inflating: DataBase_10M/Level1/cluster792.bin
#   inflating: DataBase_10M/Level1/cluster793.bin
#   inflating: DataBase_10M/Level1/cluster794.bin
#   inflating: DataBase_10M/Level1/cluster795.bin
#   inflating: DataBase_10M/Level1/cluster796.bin
#   inflating: DataBase_10M/Level1/cluster797.bin
#   inflating: DataBase_10M/Level1/cluster798.bin
#   inflating: DataBase_10M/Level1/cluster799.bin
#   inflating: DataBase_10M/Level1/cluster800.bin
#   inflating: DataBase_10M/Level1/cluster801.bin
#   inflating: DataBase_10M/Level1/cluster802.bin
#   inflating: DataBase_10M/Level1/cluster803.bin
#   inflating: DataBase_10M/Level1/cluster804.bin
#   inflating: DataBase_10M/Level1/cluster805.bin
#   inflating: DataBase_10M/Level1/cluster806.bin
#   inflating: DataBase_10M/Level1/cluster807.bin
#   inflating: DataBase_10M/Level1/cluster808.bin
#   inflating: DataBase_10M/Level1/cluster809.bin
#   inflating: DataBase_10M/Level1/cluster810.bin
#   inflating: DataBase_10M/Level1/cluster811.bin
#   inflating: DataBase_10M/Level1/cluster812.bin
#   inflating: DataBase_10M/Level1/cluster813.bin
#   inflating: DataBase_10M/Level1/cluster814.bin
#   inflating: DataBase_10M/Level1/cluster815.bin
#   inflating: DataBase_10M/Level1/cluster816.bin
#   inflating: DataBase_10M/Level1/cluster817.bin
#   inflating: DataBase_10M/Level1/cluster818.bin
#   inflating: DataBase_10M/Level1/cluster819.bin
#   inflating: DataBase_10M/Level1/cluster820.bin
#   inflating: DataBase_10M/Level1/cluster821.bin
#   inflating: DataBase_10M/Level1/cluster822.bin
#   inflating: DataBase_10M/Level1/cluster823.bin
#   inflating: DataBase_10M/Level1/cluster824.bin
#   inflating: DataBase_10M/Level1/cluster825.bin
#   inflating: DataBase_10M/Level1/cluster826.bin
#   inflating: DataBase_10M/Level1/cluster827.bin
#   inflating: DataBase_10M/Level1/cluster828.bin
#   inflating: DataBase_10M/Level1/cluster829.bin
#   inflating: DataBase_10M/Level1/cluster830.bin
#   inflating: DataBase_10M/Level1/cluster831.bin
#   inflating: DataBase_10M/Level1/cluster832.bin
#   inflating: DataBase_10M/Level1/cluster833.bin
#   inflating: DataBase_10M/Level1/cluster834.bin
#   inflating: DataBase_10M/Level1/cluster835.bin
#   inflating: DataBase_10M/Level1/cluster836.bin
#   inflating: DataBase_10M/Level1/cluster837.bin
#   inflating: DataBase_10M/Level1/cluster838.bin
#   inflating: DataBase_10M/Level1/cluster839.bin
#   inflating: DataBase_10M/Level1/cluster840.bin
#   inflating: DataBase_10M/Level1/cluster841.bin
#   inflating: DataBase_10M/Level1/cluster842.bin
#   inflating: DataBase_10M/Level1/cluster843.bin
#   inflating: DataBase_10M/Level1/cluster844.bin
#   inflating: DataBase_10M/Level1/cluster845.bin
#   inflating: DataBase_10M/Level1/cluster846.bin
#   inflating: DataBase_10M/Level1/cluster847.bin
#   inflating: DataBase_10M/Level1/cluster848.bin
#   inflating: DataBase_10M/Level1/cluster849.bin
#   inflating: DataBase_10M/Level1/cluster850.bin
#   inflating: DataBase_10M/Level1/cluster851.bin
#   inflating: DataBase_10M/Level1/cluster852.bin
#   inflating: DataBase_10M/Level1/cluster853.bin
#   inflating: DataBase_10M/Level1/cluster854.bin
#   inflating: DataBase_10M/Level1/cluster855.bin
#   inflating: DataBase_10M/Level1/cluster856.bin
#   inflating: DataBase_10M/Level1/cluster857.bin
#   inflating: DataBase_10M/Level1/cluster858.bin
#   inflating: DataBase_10M/Level1/cluster859.bin
#   inflating: DataBase_10M/Level1/cluster860.bin
#   inflating: DataBase_10M/Level1/cluster861.bin
#   inflating: DataBase_10M/Level1/cluster862.bin
#   inflating: DataBase_10M/Level1/cluster863.bin
#   inflating: DataBase_10M/Level1/cluster864.bin
#   inflating: DataBase_10M/Level1/cluster865.bin
#   inflating: DataBase_10M/Level1/cluster866.bin
#   inflating: DataBase_10M/Level1/cluster867.bin
#   inflating: DataBase_10M/Level1/cluster868.bin
#   inflating: DataBase_10M/Level1/cluster869.bin
#   inflating: DataBase_10M/Level1/cluster870.bin
#   inflating: DataBase_10M/Level1/cluster871.bin
#   inflating: DataBase_10M/Level1/cluster872.bin
#   inflating: DataBase_10M/Level1/cluster873.bin
#   inflating: DataBase_10M/Level1/cluster874.bin
#   inflating: DataBase_10M/Level1/cluster875.bin
#   inflating: DataBase_10M/Level1/cluster876.bin
#   inflating: DataBase_10M/Level1/cluster877.bin
#   inflating: DataBase_10M/Level1/cluster878.bin
#   inflating: DataBase_10M/Level1/cluster879.bin
#   inflating: DataBase_10M/Level1/cluster880.bin
#   inflating: DataBase_10M/Level1/cluster881.bin
#   inflating: DataBase_10M/Level1/cluster882.bin
#   inflating: DataBase_10M/Level1/cluster883.bin
#   inflating: DataBase_10M/Level1/cluster884.bin
#   inflating: DataBase_10M/Level1/cluster885.bin
#   inflating: DataBase_10M/Level1/cluster886.bin
#   inflating: DataBase_10M/Level1/cluster887.bin
#   inflating: DataBase_10M/Level1/cluster888.bin
#   inflating: DataBase_10M/Level1/cluster889.bin
#   inflating: DataBase_10M/Level1/cluster890.bin
#   inflating: DataBase_10M/Level1/cluster891.bin
#   inflating: DataBase_10M/Level1/cluster892.bin
#   inflating: DataBase_10M/Level1/cluster893.bin
#   inflating: DataBase_10M/Level1/cluster894.bin
#   inflating: DataBase_10M/Level1/cluster895.bin
#   inflating: DataBase_10M/Level1/cluster896.bin
#   inflating: DataBase_10M/Level1/cluster897.bin
#   inflating: DataBase_10M/Level1/cluster898.bin
#   inflating: DataBase_10M/Level1/cluster899.bin
#   inflating: DataBase_10M/Level1/cluster900.bin
#   inflating: DataBase_10M/Level1/cluster901.bin
#   inflating: DataBase_10M/Level1/cluster902.bin
#   inflating: DataBase_10M/Level1/cluster903.bin
#   inflating: DataBase_10M/Level1/cluster904.bin
#   inflating: DataBase_10M/Level1/cluster905.bin
#   inflating: DataBase_10M/Level1/cluster906.bin
#   inflating: DataBase_10M/Level1/cluster907.bin
#   inflating: DataBase_10M/Level1/cluster908.bin
#   inflating: DataBase_10M/Level1/cluster909.bin
#   inflating: DataBase_10M/Level1/cluster910.bin
#   inflating: DataBase_10M/Level1/cluster911.bin
#   inflating: DataBase_10M/Level1/cluster912.bin
#   inflating: DataBase_10M/Level1/cluster913.bin
#   inflating: DataBase_10M/Level1/cluster914.bin
#   inflating: DataBase_10M/Level1/cluster915.bin
#   inflating: DataBase_10M/Level1/cluster916.bin
#   inflating: DataBase_10M/Level1/cluster917.bin
#   inflating: DataBase_10M/Level1/cluster918.bin
#   inflating: DataBase_10M/Level1/cluster919.bin
#   inflating: DataBase_10M/Level1/cluster920.bin
#   inflating: DataBase_10M/Level1/cluster921.bin
#   inflating: DataBase_10M/Level1/cluster922.bin
#   inflating: DataBase_10M/Level1/cluster923.bin
#   inflating: DataBase_10M/Level1/cluster924.bin
#   inflating: DataBase_10M/Level1/cluster925.bin
#   inflating: DataBase_10M/Level1/cluster926.bin
#   inflating: DataBase_10M/Level1/cluster927.bin
#   inflating: DataBase_10M/Level1/cluster928.bin
#   inflating: DataBase_10M/Level1/cluster929.bin
#   inflating: DataBase_10M/Level1/cluster930.bin
#   inflating: DataBase_10M/Level1/cluster931.bin
#   inflating: DataBase_10M/Level1/cluster932.bin
#   inflating: DataBase_10M/Level1/cluster933.bin
#   inflating: DataBase_10M/Level1/cluster934.bin
#   inflating: DataBase_10M/Level1/cluster935.bin
#   inflating: DataBase_10M/Level1/cluster936.bin
#   inflating: DataBase_10M/Level1/cluster937.bin
#   inflating: DataBase_10M/Level1/cluster938.bin
#   inflating: DataBase_10M/Level1/cluster939.bin
#   inflating: DataBase_10M/Level1/cluster940.bin
#   inflating: DataBase_10M/Level1/cluster941.bin
#   inflating: DataBase_10M/Level1/cluster942.bin
#   inflating: DataBase_10M/Level1/cluster943.bin
#   inflating: DataBase_10M/Level1/cluster944.bin
#   inflating: DataBase_10M/Level1/cluster945.bin
#   inflating: DataBase_10M/Level1/cluster946.bin
#   inflating: DataBase_10M/Level1/cluster947.bin
#   inflating: DataBase_10M/Level1/cluster948.bin
#   inflating: DataBase_10M/Level1/cluster949.bin
#   inflating: DataBase_10M/Level1/cluster950.bin
#   inflating: DataBase_10M/Level1/cluster951.bin
#   inflating: DataBase_10M/Level1/cluster952.bin
#   inflating: DataBase_10M/Level1/cluster953.bin
#   inflating: DataBase_10M/Level1/cluster954.bin
#   inflating: DataBase_10M/Level1/cluster955.bin
#   inflating: DataBase_10M/Level1/cluster956.bin
#   inflating: DataBase_10M/Level1/cluster957.bin
#   inflating: DataBase_10M/Level1/cluster958.bin
#   inflating: DataBase_10M/Level1/cluster959.bin
#   inflating: DataBase_10M/Level1/cluster960.bin
#   inflating: DataBase_10M/Level1/cluster961.bin
#   inflating: DataBase_10M/Level1/cluster962.bin
#   inflating: DataBase_10M/Level1/cluster963.bin
#   inflating: DataBase_10M/Level1/cluster964.bin
#   inflating: DataBase_10M/Level1/cluster965.bin
#   inflating: DataBase_10M/Level1/cluster966.bin
#   inflating: DataBase_10M/Level1/cluster967.bin
#   inflating: DataBase_10M/Level1/cluster968.bin
#   inflating: DataBase_10M/Level1/cluster969.bin
#   inflating: DataBase_10M/Level1/cluster970.bin
#   inflating: DataBase_10M/Level1/cluster971.bin
#   inflating: DataBase_10M/Level1/cluster972.bin
#   inflating: DataBase_10M/Level1/cluster973.bin
#   inflating: DataBase_10M/Level1/cluster974.bin
#   inflating: DataBase_10M/Level1/cluster975.bin
#   inflating: DataBase_10M/Level1/cluster976.bin
#   inflating: DataBase_10M/Level1/cluster977.bin
#   inflating: DataBase_10M/Level1/cluster978.bin
#   inflating: DataBase_10M/Level1/cluster979.bin
#   inflating: DataBase_10M/Level1/cluster980.bin
#   inflating: DataBase_10M/Level1/cluster981.bin
#   inflating: DataBase_10M/Level1/cluster982.bin
#   inflating: DataBase_10M/Level1/cluster983.bin
#   inflating: DataBase_10M/Level1/cluster984.bin
#   inflating: DataBase_10M/Level1/cluster985.bin
#   inflating: DataBase_10M/Level1/cluster986.bin
#   inflating: DataBase_10M/Level1/cluster987.bin
#   inflating: DataBase_10M/Level1/cluster988.bin
#   inflating: DataBase_10M/Level1/cluster989.bin
#   inflating: DataBase_10M/Level1/cluster990.bin
#   inflating: DataBase_10M/Level1/cluster991.bin
#   inflating: DataBase_10M/Level1/cluster992.bin
#   inflating: DataBase_10M/Level1/cluster993.bin
#   inflating: DataBase_10M/Level1/cluster994.bin
#   inflating: DataBase_10M/Level1/cluster995.bin
#   inflating: DataBase_10M/Level1/cluster996.bin
#   inflating: DataBase_10M/Level1/cluster997.bin
#   inflating: DataBase_10M/Level1/cluster998.bin
#   inflating: DataBase_10M/Level1/cluster999.bin
#    creating: DataBase_10M/.ipynb_checkpoints/
#   inflating: DataBase_10M/data.bin
# DataBase_10M/data.bin:  write error (disk full?).  Continue? (y/n/^C)

# %% [markdown]
# These are the functions for running and reporting

# %%
import numpy as np
from vec_db import VecDB
import time
from dataclasses import dataclass
from typing import List
from memory_profiler import memory_usage
import gc

@dataclass
class Result:
    run_time: float
    top_k: int
    db_ids: List[int]
    actual_ids: List[int]

results = []
to_print_arr = []

def run_queries(db, query, top_k, actual_ids, num_runs):
    global results
    results = []
    for _ in range(num_runs):
        tic = time.time()
        db_ids = db.retrive(query, top_k)
        toc = time.time()
        run_time = toc - tic
        results.append(Result(run_time, top_k, db_ids, actual_ids))
    return results

def memory_usage_run_queries(args):
    global results
    # This part is added to calcauate the RAM usage
    mem_before = max(memory_usage())
    mem = memory_usage(proc=(run_queries, args, {}), interval = 1e-3)
    return results, max(mem) - mem_before

def evaluate_result(results: List[Result]):
    # scores are negative. So getting 0 is the best score.
    scores = []
    run_time = []
    for res in results:
        run_time.append(res.run_time)
        # case for retireving number not equal to top_k, socre will be the lowest
        if len(set(res.db_ids)) != res.top_k or len(res.db_ids) != res.top_k:
            scores.append( -1 * len(res.actual_ids) * res.top_k)
            continue
        score = 0
        for id in res.db_ids:
            try:
                ind = res.actual_ids.index(id)
                if ind > res.top_k * 3:
                    score -= ind
            except:
                score -= len(res.actual_ids)
        scores.append(score)

    return sum(scores) / len(scores), sum(run_time) / len(run_time)

def get_actual_ids_first_k(actual_sorted_ids, k):
    return [id for id in actual_sorted_ids if id < k]

# %% [markdown]
# This to generate 10K database and the query using the seed numbers that will be changed at submissions day

# %%
rng = np.random.default_rng(DB_SEED_NUMBER)
vectors = rng.random((10**4, 70), dtype=np.float32)

rng = np.random.default_rng(QUERY_SEED_NUMBER)
query = rng.random((1, 70), dtype=np.float32)

actual_sorted_ids_10k = np.argsort(vectors.dot(query.T).T / (np.linalg.norm(vectors, axis=1) * np.linalg.norm(query)), axis= 1).squeeze().tolist()[::-1]

# %% [markdown]
# Open new DB add 10K then retrieve and evaluate. Then add another 90K (total 100K) then retrieve and evaluate.

# %%
db = VecDB()

records_dict = [{"id": i, "embed": list(row)} for i, row in enumerate(vectors)]
db.insert_records(records_dict)
res = run_queries(db, query, 5, actual_sorted_ids_10k, 1) # one run to make everything fresh and loaded
res, mem = memory_usage_run_queries((db, query, 5, actual_sorted_ids_10k, 5)) # actual runs to compute time, and memory
eval = evaluate_result(res)
to_print = f"10K\tscore\t{eval[0]}\ttime\t{eval[1]:.2f}\tRAM\t{mem:.2f} MB"
to_print_arr.append(to_print)
print(to_print)

# %% [markdown]
# Remove exsiting varaibles to empty some RAM

# %%
del vectors
del query
del actual_sorted_ids_10k
del records_dict
del db
gc.collect()

# %% [markdown]
# This code to generate 20M database. The seed (50) will not be changed. Create the same DB and prepare it's files indexes and every related file. <br>
# Note at the submission I'll not run the insert records. <br>
# The query istelf will be changed at submissions day but not the DB

# %%
rng = np.random.default_rng(50)
vectors = rng.random((10**7*2, 70), dtype=np.float32)

rng = np.random.default_rng(QUERY_SEED_NUMBER)
query = rng.random((1, 70), dtype=np.float32)

actual_sorted_ids_20m = np.argsort(vectors.dot(query.T).T / (np.linalg.norm(vectors, axis=1) * np.linalg.norm(query)), axis= 1).squeeze().tolist()[::-1]

# %%
print("Team Number", TEAM_NUMBER)
print("\n".join(to_print_arr))

db = VecDB(file_path = PATH_DB_100K, new_db = False)
actual_ids = get_actual_ids_first_k(actual_sorted_ids_20m, 10**5)
res = run_queries(db, query, 5, actual_ids, 1)  # one run to make everything fresh and loaded
res, mem = memory_usage_run_queries((db, query, 5, actual_ids, 3)) # actual runs to compute time, and memory
eval = evaluate_result(res)
to_print = f"100K\tscore\t{eval[0]}\ttime\t{eval[1]:.2f}\tRAM\t{mem:.2f} MB"
to_print_arr.append(to_print)
print(to_print)


db = VecDB(file_path = PATH_DB_1M, new_db = False)
actual_ids = get_actual_ids_first_k(actual_sorted_ids_20m, 10**6)
res = run_queries(db, query, 5, actual_ids, 1)  # one run to make everything fresh and loaded
res, mem = memory_usage_run_queries((db, query, 5, actual_ids, 3)) # actual runs to compute time, and memory
eval = evaluate_result(res)
to_print = f"1M\tscore\t{eval[0]}\ttime\t{eval[1]:.2f}\tRAM\t{mem:.2f} MB"
to_print_arr.append(to_print)
print(to_print)


db = VecDB(file_path = PATH_DB_5M, new_db = False)
actual_ids = get_actual_ids_first_k(actual_sorted_ids_20m, 10**6*5)
res = run_queries(db, query, 5, actual_ids, 1)  # one run to make everything fresh and loaded
res, mem = memory_usage_run_queries((db, query, 5, actual_ids, 3)) # actual runs to compute time, and memory
eval = evaluate_result(res)
to_print = f"5M\tscore\t{eval[0]}\ttime\t{eval[1]:.2f}\tRAM\t{mem:.2f} MB"
to_print_arr.append(to_print)
print(to_print)


db = VecDB(file_path = PATH_DB_10M, new_db = False)
actual_ids = get_actual_ids_first_k(actual_sorted_ids_20m, 10**6*10)
res = run_queries(db, query, 5, actual_ids, 1)  # one run to make everything fresh and loaded
res, mem = memory_usage_run_queries((db, query, 5, actual_ids, 3)) # actual runs to compute time, and memory
eval = evaluate_result(res)
to_print = f"10M\tscore\t{eval[0]}\ttime\t{eval[1]:.2f}\tRAM\t{mem:.2f} MB"
to_print_arr.append(to_print)
print(to_print)


db = VecDB(file_path = PATH_DB_15M, new_db = False)
actual_ids = get_actual_ids_first_k(actual_sorted_ids_20m, 10**6*15)
res = run_queries(db, query, 5, actual_ids, 1)  # one run to make everything fresh and loaded
res, mem = memory_usage_run_queries((db, query, 5, actual_ids, 3)) # actual runs to compute time, and memory
eval = evaluate_result(res)
to_print = f"15M\tscore\t{eval[0]}\ttime\t{eval[1]:.2f}\tRAM\t{mem:.2f} MB"
to_print_arr.append(to_print)
print(to_print)


db = VecDB(file_path = PATH_DB_20M, new_db = False)
actual_ids = get_actual_ids_first_k(actual_sorted_ids_20m, 10**6*20)
res = run_queries(db, query, 5, actual_ids, 1)  # one run to make everything fresh and loaded
res, mem = memory_usage_run_queries((db, query, 5, actual_ids, 3)) # actual runs to compute time, and memory
eval = evaluate_result(res)
to_print = f"20M\tscore\t{eval[0]}\ttime\t{eval[1]:.2f}\tRAM\t{mem:.2f} MB"
to_print_arr.append(to_print)
print(to_print)

# %%
print("Team Number", TEAM_NUMBER)
print("\n".join(to_print_arr))
